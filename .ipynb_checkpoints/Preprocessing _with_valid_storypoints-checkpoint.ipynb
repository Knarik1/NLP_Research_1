# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
import string     
from bs4 import BeautifulSoup
from collections import defaultdict

import nltk
from nltk.tokenize import word_tokenize, WhitespaceTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import spacy

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC 
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier 
from sklearn.metrics import accuracy_score

#nltk.download('punkt')
#nltk.download('stopwords')

stop_words = stopwords.words('english')
sp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## All Data information

# %%
# read all datasets
df_appceleratorstudio = pd.read_csv('./data/appceleratorstudio.csv')
df_aptanastudio = pd.read_csv('./data/aptanastudio.csv')
df_bamboo = pd.read_csv('./data/bamboo.csv')
df_clover = pd.read_csv('./data/clover.csv')
df_datamanagement = pd.read_csv('./data/datamanagement.csv')
df_duracloud = pd.read_csv('./data/duracloud.csv')
df_jirasoftware = pd.read_csv('./data/jirasoftware.csv')
df_mesos = pd.read_csv('./data/mesos.csv')
df_moodle = pd.read_csv('./data/moodle.csv')
df_mule = pd.read_csv('./data/mule.csv')
df_mulestudio = pd.read_csv('./data/mulestudio.csv')
df_springxd = pd.read_csv('./data/springxd.csv')
df_talenddataquality = pd.read_csv('./data/talenddataquality.csv')
df_talendesb = pd.read_csv('./data/talendesb.csv')
df_titanium = pd.read_csv('./data/titanium.csv')
df_usergrid = pd.read_csv('./data/usergrid.csv')

# %%
# union all datasets
df_all = pd.concat([
    df_appceleratorstudio,
    df_aptanastudio,
    df_bamboo,
    df_clover,
    df_datamanagement,
    df_duracloud,
    df_jirasoftware,
    df_mesos,
    df_moodle,
    df_mule,
    df_mulestudio,
    df_springxd,
    df_talenddataquality,
    df_talendesb,
    df_titanium,
    df_usergrid
], ignore_index=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23313 entries, 0 to 23312
# Data columns (total 4 columns):
# issuekey       23313 non-null object
# title          23313 non-null object
# description    21082 non-null object
# storypoint     23313 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 728.6+ KB

# %%
# converting storypoint column type int->str
df_all['storypoint'] = df_all['storypoint'].astype(str)
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23313 entries, 0 to 23312
# Data columns (total 4 columns):
# issuekey       23313 non-null object
# title          23313 non-null object
# description    21082 non-null object
# storypoint     23313 non-null object
# dtypes: object(4)
# memory usage: 728.6+ KB

# %%
# count all missing values
for col in df_all.columns:
    print(col, df_all[col].isnull().sum())
# Out:
# issuekey 0
# title 0
# description 2231
# storypoint 0

# %%
# show all missing value rows
df_all[df_all.isna().any(axis=1)]
# Out:
#             issuekey                                              title  \
# 44        TISTUD-136     Add user-agent icons for iPhone, iPad, Android
# 74        TISTUD-280           Add domain and login to cloud app wizard
# 107       TISTUD-407  Confirm TiStudio default update set is set to ...
# 114       TISTUD-475                  Add unit tests for TiAppModelUtil
# 115       TISTUD-476             Add unit tests for TitaniumUpdaterUtil
# 116       TISTUD-477                 Add unit tests for MobileUsageUtil
# 117       TISTUD-478                Add unit tests for DesktopUsageUtil
# 118       TISTUD-479  Add unit tests for SDKLocator, SDKManager, SDK...
# 123       TISTUD-492  Create feature and builder for TiStudio unit t...
# 131       TISTUD-518          Look into adding unit tests for packaging
# 164       TISTUD-775  Disable the V8 option in the TiApp editor when...
# 185       TISTUD-887                   display background from PSD file
# 201       TISTUD-959                        Implement Snippet Filtering
# 222      TISTUD-1051   Externalize UI strings in Titanium Desktop ruble
# 223      TISTUD-1052    Externalize UI strings in Titanium Mobile ruble
# 225      TISTUD-1055                 Create test plan for Snippets view
# 233      TISTUD-1079  Exclude build folder from text search made in ...
# 257      TISTUD-1167  Investigate ability to auto-scroll lock the co...
# 258      TISTUD-1168  Add Common Interface for consolidating UI erro...
# 432      TISTUD-1511  Run Android preference page loading in the bac...
# 468      TISTUD-1590  Split titanium mobile plugin into ui and core ...
# 663      TISTUD-2008  The typo in the new signup page: should say "p...
# 685      TISTUD-2048  Update "Explore" tab to show list of my module...
# 686      TISTUD-2049  Reflect current status of each module in explo...
# 687      TISTUD-2050  When clicking link to install module, run modu...
# 707      TISTUD-2083  Investigate if the CTRL-SHIFT-W is related to ...
# 708      TISTUD-2084  Investigate if the CTRL+SHIFT+W is related to ...
# 969      TISTUD-2666   Content overlay - icon, description etc for D...
# 982      TISTUD-2714  Change the wizard image in Update wizard to lo...
# 983      TISTUD-2715  Add user id field to the password sudo page in...
# ...              ...                                                ...
# 23215   USERGRID-898  Add proper error checking to Asset Code along ...
# 23223   USERGRID-908                             run specific migration
# 23226   USERGRID-914   Blog post for 10k TPS and horizontal scalability
# 23230   USERGRID-929  Test the creation of entities which have an Ol...
# 23231   USERGRID-933  [SPIKE] Understand what remains and break up t...
# 23237   USERGRID-941  Spike: Investigate using Java Annotations to g...
# 23240   USERGRID-950  Remove Cassandra Keyspace name from Index Nami...
# 23242   USERGRID-991                 Fix tests after Jersey 2.0 upgrade
# 23243   USERGRID-992                        Enable Org-level properties
# 23246  USERGRID-1005   Add Background processing for delete application
# 23248  USERGRID-1013        Automate upload of api baas 2.1 build to s3
# 23249  USERGRID-1015                       Test Notification Migration
# 23253  USERGRID-1022                remove batching in index processing
# 23254  USERGRID-1023  Delete from collection does not use SQS or the...
# 23260  USERGRID-1032  Test and confirm Usergrid 2.1 works with Cassa...
# 23261  USERGRID-1033  Test and confirm Usergrid 2.0 works with Cassa...
# 23264  USERGRID-1038    2.1-release: fix index batching from SQS reader
# 23273  USERGRID-1069                 implement build metrics in jenkins
# 23274  USERGRID-1071                        Test iOS push notifications
# 23275  USERGRID-1072                    Test Android push notifications
# 23276  USERGRID-1073                                 Test Windows phone
# 23277  USERGRID-1074  [SPIKE] Evaluate read repair of unique values ...
# 23282  USERGRID-1085          Create RPM Distributable for Usergrid 2.1
# 23286  USERGRID-1093  Load test in-memory queue with current consume...
# 23288  USERGRID-1100  POST /users/{user}/devices/notifications does ...
# 23294  USERGRID-1119       Fix GroupResourceIT.postGroupActivity() test
# 23296  USERGRID-1182     Support GCM 3.0 for Android Push Notifications
# 23301  USERGRID-1203  Allow certs in notifiers to be updated and sto...
# 23302  USERGRID-1209  GET on missing Asset file in S3 generates 500 ...
# 23308  USERGRID-1256  Introduce Datastax Java Driver in effort to mi...
#
#       description storypoint
# 44            NaN          1
# 74            NaN          1
# 107           NaN          1
# 114           NaN          1
# 115           NaN          1
# 116           NaN          1
# 117           NaN          1
# 118           NaN          1
# 123           NaN          1
# 131           NaN          1
# 164           NaN          1
# 185           NaN          1
# 201           NaN         13
# 222           NaN          2
# 223           NaN          2
# 225           NaN          8
# 233           NaN          8
# 257           NaN          8
# 258           NaN          5
# 432           NaN          8
# 468           NaN          8
# 663           NaN          2
# 685           NaN         13
# 686           NaN         13
# 687           NaN         13
# 707           NaN          8
# 708           NaN          8
# 969           NaN          8
# 982           NaN          8
# 983           NaN          3
# ...           ...        ...
# 23215         NaN          3
# 23223         NaN          1
# 23226         NaN          2
# 23230         NaN          1
# 23231         NaN          3
# 23237         NaN          5
# 23240         NaN          1
# 23242         NaN          5
# 23243         NaN          5
# 23246         NaN          2
# 23248         NaN          3
# 23249         NaN          3
# 23253         NaN          1
# 23254         NaN          3
# 23260         NaN          2
# 23261         NaN          1
# 23264         NaN          3
# 23273         NaN          1
# 23274         NaN          1
# 23275         NaN          1
# 23276         NaN          1
# 23277         NaN          1
# 23282         NaN          5
# 23286         NaN          3
# 23288         NaN          1
# 23294         NaN          3
# 23296         NaN          2
# 23301         NaN          1
# 23302         NaN          1
# 23308         NaN          1
#
# [2231 rows x 4 columns]

# %%
# storypoint frequencies
# should be Fibonacci-like format: 0, 0.5????, 1, 2, 3, 5, 8, 13, 20, 40, 100. 
# but here we have 21, 4, 9, 34,... anomaly)))
df_all['storypoint'].value_counts()
# Out:
# 5      4319
# 1      4225
# 3      3973
# 2      3406
# 8      3112
# 13      981
# 4       836
# 20      452
# 6       406
# 10      389
# 40      182
# 21      117
# 100     111
# 12       82
# 15       69
# 16       59
# 30       58
# 7        53
# 9        34
# 34       30
# 14       26
# 60       25
# 50       23
# 79       21
# 11       21
# 19       20
# 17       20
# 26       18
# 53       18
# 18       16
#        ...
# 70        4
# 90        4
# 31        4
# 52        3
# 27        3
# 47        3
# 43        2
# 48        2
# 64        2
# 55        2
# 63        1
# 95        1
# 69        1
# 71        1
# 96        1
# 51        1
# 88        1
# 84        1
# 46        1
# 57        1
# 68        1
# 92        1
# 83        1
# 66        1
# 58        1
# 41        1
# 94        1
# 82        1
# 89        1
# 73        1
# Name: storypoint, Length: 80, dtype: int64

# %%
plt.figure(figsize=(17,5))
df_all['storypoint'].value_counts().plot(kind='bar')
plt.title('Storypoint Distribution', fontsize=15);

# %%
# valid label names
label_names = ['1', '2', '3', '5', '8', '13', '20', '40', '100']

# %%
# checking valid storypoints count, it's about 89%
len([v for v in df_all['storypoint'].values if v in label_names])
# Out:
# 20761

# %%
# new dataframe with valid datapoints
df_all = df_all.loc[df_all['storypoint'].isin(label_names)]
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20761 entries, 0 to 23312
# Data columns (total 4 columns):
# issuekey       20761 non-null object
# title          20761 non-null object
# description    18918 non-null object
# storypoint     20761 non-null object
# dtypes: object(4)
# memory usage: 811.0+ KB

# %%
# count all missing values
for col in df_all.columns:
    print(col, df_all[col].isnull().sum())
# Out:
# issuekey 0
# title 0
# description 1843
# storypoint 0

# %%
plt.figure(figsize=(17,5))
df_all['storypoint'].value_counts().plot(kind='bar')
plt.title('Storypoint Distribution', fontsize=15);

# %% [markdown]
# ## Preprocessing

# %%
labels = df_all["storypoint"].values
X = df_all.drop(["issuekey", "storypoint"], axis=1)


# issuekey include???
X.head()
# Out:
#                                                title  \
# 0  Add CA against object literals in function inv...
# 1  Update branding for Appcelerator plugin to App...
# 2                Create new JSON schema for SDK team
# 3            Create Project References Property Page
# 4                         New Desktop Project Wizard
#
#                                          description
# 0  {html}<div><p>The idea here is that if our met...
# 1  {html}<div><p>At least fix feature icons, asso...
# 2  {html}<div><p>Create JSON schema containing pr...
# 3  {html}<div><p>Create property page for project...
# 4  {html}<div><p>Desktop (need to convert existin...

# %%
# replace missing values with empty strings
X = X.fillna('')

# %%
# concat title to description by space/dot?? 
# may be model will give to title more weights than to the description, so we should't concat them???
X["title_description"] = X["title"] + " " +  X["description"]
X["title_description"][2]
# Out:
# 'Create new JSON schema for SDK team {html}<div><p>Create JSON schema containing properties required for proper CA. Hand schema to Platform team to output new docs/JSON files as part of new SDK releases. It may be that instead we can use the vsdoc format, in which case we will need to indicate to the SDK team additional items to be added to the docs.</p></div>{html}'

# %%
text = X["title_description"].to_numpy()
print("text length is", len(text))
text
# Out:
# text length is 20761
# array(['Add CA against object literals in function invocations {html}<div><p>The idea here is that if our metadata captures a type as function arg, we should be able to create an instance of that type as an object literal as an arg to a function invocation. For example:</p> <pre> <code>Ti.UI.createLabel( { &lt;property-ca-here&gt; } );</code> </pre></div>{html}',
#        'Update branding for Appcelerator plugin to Appcelerator logo  {html}<div><p>At least fix feature icons, associated natures. Perhaps other screens as well.</p></div>{html}',
#        'Create new JSON schema for SDK team {html}<div><p>Create JSON schema containing properties required for proper CA. Hand schema to Platform team to output new docs/JSON files as part of new SDK releases. It may be that instead we can use the vsdoc format, in which case we will need to indicate to the SDK team additional items to be added to the docs.</p></div>{html}',
#        ...,
#        'Proof of Concept: use Akka for Unique Value enforcement By using an distributed Actor System, we can ensure that only one thread accesses any one unique value at a time. I have a working proof of concept of this that writes to Cassandra (via Java Native Driver).    Initial design is here:  https://docs.google.com/document/d/1o9okFgNb_c1RY0eIcZMhijhxE9v7BxHYDiuI8BqkLgU/edit#    Proof of Concept (POC) code is here:  https://github.com/snoopdave/akka_poc1    Presentation that explains the POC is here:  https://docs.google.com/presentation/d/11ARSPZ6IAxOYSTo4jcmEdnzXvOgVGNGslznmVtLOZjY/edit?usp=sharing  ',
#        "Set a property to turn off usergrid's dependency on elasticsearch Have a property that can tell Usergrid whether we want to use elasticsearch or not. If we don't we shouldn't have any errors, should just work as is with only graph searches . ",
#        'Allow usergrid.api.url.base to be set when creating organizations. Allowing usergrid.api.url.base this field to be set or set differently so it is not forgotten when you are running usergrid. '],
#       dtype=object)

# %%
def preprocess_txt(doc):
    #lowercase
    doc = doc.lower() 
    #remove "{html}" strings
    doc = re.sub('\{html\}', '', doc)
    #remove html tags
    doc = BeautifulSoup(doc, 'html.parser').get_text()
    #remove all paths/urls/--keys
    pattern = re.compile(r'[/\-+\\+]')
    doc_split = [token for token in WhitespaceTokenizer().tokenize(doc) if not pattern.findall(token)]
    doc = " ".join(doc_split)

    #tokenize and remove stop words and punctuation symbols and spaces using spaCy
    #use lemmas
    doc_spacy = sp(doc)
    doc_tokenized_spacy = [token.lemma_ for token in doc_spacy
        if not token.is_stop and not token.is_punct and not token.is_space]

    #preprocessing additionaly with nltk give much better results
    doc_nltk = " ".join(doc_tokenized_spacy)
    #tokenize and remove stop words and punctuation symbols using nltk 
    #remove numerics
    doc_tokenized_spacy_nltk = [token for token in nltk.word_tokenize(doc_nltk)
        if token.isalpha()]
    
    return doc_tokenized_spacy_nltk

# %%
# creating the corpus
def create_corpus(text_arr):
    corpus = []

    for doc in text_arr:
        prep_doc = preprocess_txt(doc)                            
        corpus.append(prep_doc)
        
    return corpus

# %%
corpus = create_corpus(text)
len(corpus)
# Out:
# 20761

# %%
def create_vocab(corpus):
    vocab = set(token for doc in corpus for token in doc)
    
    return vocab

# %%
vocab = create_vocab(corpus)
len(vocab)
# Out:
# 22458

# %%
# an example of preprocessing before/after

print("---------------Original text------------------\n")
doc = text[7865]
print(doc)
doc = doc.lower()
doc = doc.replace('\{html\}', '')
doc = BeautifulSoup(doc, 'html.parser').get_text()

print("\n---------------After removing paths/urls/--keys------------------\n")
pattern = re.compile(r'[/\-+\\+]')
doc_split = [token for token in WhitespaceTokenizer().tokenize(doc) if not pattern.findall(token)]
doc = " ".join(doc_split)

print(doc_split)

#preprocessing with only spaCy
print("\n---------------spaCy prep + lemma------------------\n")
doc_spacy = sp(doc)
doc_tokenized_spacy = [token.lemma_ for token in doc_spacy
    if not token.is_stop and not token.is_punct and not token.is_space]
print(doc_tokenized_spacy)

#preprocessing with spaCy + nltk
# print("\n---------------spaCy + lemma + nltk prep + is_not_numeric-----------------\n")
# doc_nltk = " ".join(doc_tokenized_spacy)
# doc_tokenized_spacy_nltk = [token for token in nltk.word_tokenize(doc_nltk)
#     if token not in stop_words and token not in string.punctuation and not token.isnumeric()]
# print(doc_tokenized_spacy_nltk)

print("\n---------------spaCy + lemma + nltk prep + isalpha-----------------\n")
doc_nltk = " ".join(doc_tokenized_spacy)
doc_tokenized_spacy_nltk = [token for token in nltk.word_tokenize(doc_nltk)
    if token not in stop_words and token not in string.punctuation and token.isalpha()]
print(doc_tokenized_spacy_nltk)
# Out:
# ---------------Original text------------------
#
# Can only perform a bulk action (e.g. deletion) on a maximum of 2 spaces at a time Today I went in to cleanup some old demo/test content in 'dspacetest.duracloud.org'.  When I selected multiple spaces, I found that no matter how many spaces I selected, the total always read "2 space(s) selected".   Even worse, I selected a total of 5 spaces and clicked "Delete Selected Spaces" button.  Only the first 2 spaces I selected were deleted.  The other 3 were kept.  It seems as though the multi-select option only captures the first two spaces you select...after that, any other selections are ignored.  Carissa has verified that this also seems to occur on demo.duracloud.org.
#
# ---------------After removing paths/urls/--keys------------------
#
# ['can', 'only', 'perform', 'a', 'bulk', 'action', '(e.g.', 'deletion)', 'on', 'a', 'maximum', 'of', '2', 'spaces', 'at', 'a', 'time', 'today', 'i', 'went', 'in', 'to', 'cleanup', 'some', 'old', 'content', 'in', "'dspacetest.duracloud.org'.", 'when', 'i', 'selected', 'multiple', 'spaces,', 'i', 'found', 'that', 'no', 'matter', 'how', 'many', 'spaces', 'i', 'selected,', 'the', 'total', 'always', 'read', '"2', 'space(s)', 'selected".', 'even', 'worse,', 'i', 'selected', 'a', 'total', 'of', '5', 'spaces', 'and', 'clicked', '"delete', 'selected', 'spaces"', 'button.', 'only', 'the', 'first', '2', 'spaces', 'i', 'selected', 'were', 'deleted.', 'the', 'other', '3', 'were', 'kept.', 'it', 'seems', 'as', 'though', 'the', 'option', 'only', 'captures', 'the', 'first', 'two', 'spaces', 'you', 'select...after', 'that,', 'any', 'other', 'selections', 'are', 'ignored.', 'carissa', 'has', 'verified', 'that', 'this', 'also', 'seems', 'to', 'occur', 'on', 'demo.duracloud.org.']
#
# ---------------spaCy prep + lemma------------------
#
# ['perform', 'bulk', 'action', 'e.g.', 'deletion', 'maximum', '2', 'space', 'time', 'today', 'go', 'cleanup', 'old', 'content', 'dspacetest.duracloud.org', 'select', 'multiple', 'space', 'find', 'matter', 'space', 'select', 'total', 'read', '2', 'space(s', 'select', 'worse', 'select', 'total', '5', 'space', 'click', 'delete', 'select', 'space', 'button', '2', 'space', 'select', 'delete', '3', 'keep', 'option', 'capture', 'space', 'select', 'selection', 'ignore', 'carissa', 'verify', 'occur', 'demo.duracloud.org']
#
# ---------------spaCy + lemma + nltk prep + isalpha-----------------
#
# ['perform', 'bulk', 'action', 'deletion', 'maximum', 'space', 'time', 'today', 'go', 'cleanup', 'old', 'content', 'select', 'multiple', 'space', 'find', 'matter', 'space', 'select', 'total', 'read', 'space', 'select', 'worse', 'select', 'total', 'space', 'click', 'delete', 'select', 'space', 'button', 'space', 'select', 'delete', 'keep', 'option', 'capture', 'space', 'select', 'selection', 'ignore', 'carissa', 'verify', 'occur']

# %%
def show_most_freq_n(corp, n):
    allwords = [token for doc in corp for token in doc]
    
    # word freqs    
    mostcommon_small = nltk.FreqDist(allwords).most_common(n)
    print(mostcommon_small)
    x, y = zip(*mostcommon_small)
    plt.figure(figsize=(50,30))
    plt.margins(0.02)
    plt.bar(x, y)
    plt.xlabel('Words', fontsize=50)
    plt.ylabel('Frequency of Words', fontsize=50)
    plt.yticks(fontsize=40)
    plt.xticks(rotation=60, fontsize=40)
    plt.title('Frequency of {} Most Common Words'.format(n), fontsize=60)
    plt.show()

# %%
show_most_freq_n(corpus, 50)
# Out:
# [('code', 9877), ('error', 8391), ('file', 6569), ('create', 6527), ('add', 5689), ('test', 5017), ('project', 4985), ('studio', 4860), ('new', 4833), ('run', 4819), ('build', 4713), ('user', 4403), ('result', 4334), ('use', 4320), ('need', 4235), ('module', 4124), ('update', 3885), ('step', 3543), ('fail', 3443), ('version', 3438), ('app', 3295), ('message', 3247), ('set', 3191), ('work', 3184), ('info', 3183), ('support', 3157), ('change', 3142), ('android', 3013), ('log', 2864), ('issue', 2665), ('titanium', 2664), ('window', 2642), ('default', 2611), ('sdk', 2543), ('like', 2423), ('var', 2405), ('start', 2385), ('property', 2382), ('type', 2300), ('method', 2234), ('value', 2226), ('expect', 2223), ('open', 2219), ('job', 2212), ('select', 2188), ('function', 2156), ('line', 2144), ('master', 2076), ('source', 2068), ('remove', 2042)]

# %%
def build_cond_freqs(corpus, labels):
    pairs = []
    for doc, label in zip(corpus, labels):
        for token in doc:
            pair = (str(label), token)
            pairs.append(pair)
    print(len(pairs))
    freqs = nltk.ConditionalFreqDist(pairs)
    
    return freqs

# %%
cond_freqs = build_cond_freqs(corpus, labels)
cond_freqs.conditions()
# Out:
# 784437
# ['5', '40', '1', '20', '8', '100', '13', '2', '3']

# %%
cond_freqs["3"].most_common()
# Out:
# [('code', 2018),
#  ('error', 1957),
#  ('create', 1346),
#  ('build', 1093),
#  ('file', 1085),
#  ('test', 1065),
#  ('add', 1052),
#  ('module', 1030),
#  ('project', 1014),
#  ('studio', 918),
#  ('new', 914),
#  ('run', 895),
#  ('result', 890),
#  ('step', 886),
#  ('use', 861),
#  ('message', 801),
#  ('android', 780),
#  ('need', 765),
#  ('sdk', 760),
#  ('update', 758),
#  ('user', 741),
#  ('app', 729),
#  ('info', 723),
#  ('fail', 719),
#  ('version', 671),
#  ('set', 637),
#  ('titanium', 593),
#  ('default', 589),
#  ('method', 586),
#  ('support', 580),
#  ('work', 577),
#  ('log', 565),
#  ('change', 556),
#  ('issue', 542),
#  ('http', 539),
#  ('master', 529),
#  ('like', 513),
#  ('resource', 481),
#  ('start', 477),
#  ('service', 468),
#  ('property', 464),
#  ('job', 457),
#  ('select', 453),
#  ('source', 452),
#  ('var', 449),
#  ('value', 447),
#  ('remove', 438),
#  ('expect', 438),
#  ('open', 427),
#  ('reproduce', 424),
#  ('ios', 423),
#  ('window', 421),
#  ('type', 418),
#  ('exception', 418),
#  ('process', 416),
#  ('configuration', 415),
#  ('debug', 413),
#  ('native', 394),
#  ('slave', 393),
#  ('action', 389),
#  ('path', 385),
#  ('request', 377),
#  ('click', 371),
#  ('check', 362),
#  ('follow', 359),
#  ('option', 357),
#  ('w', 354),
#  ('allow', 354),
#  ('currently', 351),
#  ('status', 350),
#  ('field', 347),
#  ('container', 347),
#  ('function', 336),
#  ('stream', 335),
#  ('list', 334),
#  ('device', 331),
#  ('npm', 326),
#  ('return', 326),
#  ('time', 323),
#  ('event', 322),
#  ('try', 320),
#  ('exist', 319),
#  ('receive', 319),
#  ('framework', 317),
#  ('cause', 315),
#  ('find', 315),
#  ('line', 313),
#  ('task', 310),
#  ('problem', 307),
#  ('replica', 307),
#  ('launch', 303),
#  ('enable', 303),
#  ('command', 296),
#  ('connection', 294),
#  ('include', 293),
#  ('class', 289),
#  ('provide', 289),
#  ('persist', 289),
#  ('case', 289),
#  ('require', 288),
#  ('actual', 287),
#  ('install', 278),
#  ('unknown', 274),
#  ('button', 274),
#  ('server', 272),
#  ('example', 270),
#  ('entry', 269),
#  ('noformat', 269),
#  ('datum', 265),
#  ('view', 264),
#  ('note', 260),
#  ('fix', 259),
#  ('position', 258),
#  ('cli', 257),
#  ('display', 256),
#  ('directory', 256),
#  ('application', 254),
#  ('e', 250),
#  ('show', 250),
#  ('attach', 249),
#  ('take', 248),
#  ('page', 246),
#  ('able', 246),
#  ('true', 245),
#  ('deploy', 241),
#  ('xd', 240),
#  ('attempt', 239),
#  ('instead', 238),
#  ('image', 237),
#  ('null', 237),
#  ('report', 236),
#  ('d', 236),
#  ('platform', 236),
#  ('false', 233),
#  ('delete', 233),
#  ('title', 231),
#  ('api', 229),
#  ('generate', 227),
#  ('way', 226),
#  ('link', 224),
#  ('authentication', 222),
#  ('send', 221),
#  ('main', 221),
#  ('system', 219),
#  ('instal', 219),
#  ('text', 218),
#  ('column', 216),
#  ('available', 215),
#  ('package', 215),
#  ('information', 214),
#  ('config', 211),
#  ('component', 211),
#  ('write', 211),
#  ('detect', 210),
#  ('dialog', 207),
#  ('analysis', 206),
#  ('configure', 203),
#  ('implement', 202),
#  ('release', 202),
#  ('recover', 201),
#  ('number', 200),
#  ('java', 198),
#  ('base', 196),
#  ('stack', 194),
#  ('throw', 193),
#  ('runtime', 191),
#  ('look', 191),
#  ('std', 190),
#  ('sample', 188),
#  ('plugin', 187),
#  ('endpoint', 185),
#  ('script', 185),
#  ('unable', 185),
#  ('call', 185),
#  ('warning', 184),
#  ('object', 183),
#  ('import', 183),
#  ('appear', 181),
#  ('ui', 181),
#  ('custom', 181),
#  ('leveldb', 180),
#  ('parameter', 180),
#  ('feature', 180),
#  ('occur', 179),
#  ('environment', 178),
#  ('want', 177),
#  ('string', 176),
#  ('current', 176),
#  ('table', 175),
#  ('get', 174),
#  ('load', 173),
#  ('content', 172),
#  ('ti', 171),
#  ('wizard', 169),
#  ('location', 169),
#  ('instance', 168),
#  ('documentation', 168),
#  ('admin', 168),
#  ('different', 167),
#  ('implementation', 166),
#  ('define', 165),
#  ('register', 163),
#  ('mobile', 163),
#  ('registry', 162),
#  ('query', 161),
#  ('alloy', 159),
#  ('read', 159),
#  ('reference', 159),
#  ('successfully', 159),
#  ('document', 158),
#  ('library', 158),
#  ('target', 157),
#  ('data', 156),
#  ('close', 156),
#  ('contain', 155),
#  ('upgrade', 155),
#  ('plan', 154),
#  ('interface', 154),
#  ('flag', 154),
#  ('tab', 153),
#  ('output', 152),
#  ('detail', 151),
#  ('st', 150),
#  ('specify', 149),
#  ('miss', 149),
#  ('developer', 148),
#  ('crash', 147),
#  ('executor', 146),
#  ('warn', 146),
#  ('folder', 145),
#  ('handle', 145),
#  ('key', 145),
#  ('screen', 144),
#  ('description', 144),
#  ('right', 144),
#  ('state', 144),
#  ('simulator', 144),
#  ('pass', 143),
#  ('name', 141),
#  ('multiple', 141),
#  ('agent', 139),
#  ('rest', 139),
#  ('access', 138),
#  ('item', 138),
#  ('color', 137),
#  ('byte', 137),
#  ('response', 137),
#  ('menu', 136),
#  ('happen', 135),
#  ('element', 135),
#  ('dependency', 135),
#  ('screenshot', 135),
#  ('possible', 133),
#  ('url', 132),
#  ('appcelerator', 132),
#  ('store', 132),
#  ('deployment', 131),
#  ('context', 131),
#  ('execute', 131),
#  ('order', 130),
#  ('db', 130),
#  ('preference', 130),
#  ('late', 129),
#  ('give', 129),
#  ('sink', 128),
#  ('filter', 128),
#  ('clean', 128),
#  ('mode', 127),
#  ('spring', 127),
#  ('q', 127),
#  ('help', 126),
#  ('failure', 126),
#  ('long', 126),
#  ('port', 125),
#  ('consumer', 125),
#  ('root', 125),
#  ('quis', 125),
#  ('level', 125),
#  ('louis', 125),
#  ('apply', 124),
#  ('template', 124),
#  ('editor', 124),
#  ('json', 123),
#  ('epic', 123),
#  ('group', 123),
#  ('appc', 123),
#  ('authenticate', 122),
#  ('client', 122),
#  ('metadata', 122),
#  ('mesos', 122),
#  ('docker', 121),
#  ('thread', 121),
#  ('map', 120),
#  ('sure', 120),
#  ('setup', 119),
#  ('resolve', 118),
#  ('learn', 118),
#  ('doc', 118),
#  ('entity', 118),
#  ('address', 117),
#  ('const', 117),
#  ('backgroundcolor', 117),
#  ('save', 116),
#  ('point', 116),
#  ('tiapplication', 116),
#  ('invalid', 114),
#  ('single', 114),
#  ('blackberry', 114),
#  ('format', 114),
#  ('finish', 114),
#  ('xml', 113),
#  ('section', 113),
#  ('notice', 112),
#  ('cpus', 112),
#  ('operation', 111),
#  ('icon', 111),
#  ('npe', 109),
#  ('match', 109),
#  ('success', 108),
#  ('hadoop', 108),
#  ('specific', 107),
#  ('database', 107),
#  ('correct', 106),
#  ('route', 105),
#  ('mule', 105),
#  ('edit', 105),
#  ('node', 105),
#  ('management', 105),
#  ('tidrawablereference', 105),
#  ('testing', 104),
#  ('attribute', 104),
#  ('size', 104),
#  ('queue', 103),
#  ('replace', 103),
#  ('space', 103),
#  ('acceptance', 103),
#  ('permission', 103),
#  ('input', 102),
#  ('complete', 102),
#  ('variable', 102),
#  ('trace', 102),
#  ('execution', 102),
#  ('definition', 101),
#  ('sasl', 100),
#  ('etc', 100),
#  ('scheduler', 100),
#  ('ticket', 99),
#  ('internal', 97),
#  ('mount', 97),
#  ('ci', 97),
#  ('jar', 97),
#  ('provider', 96),
#  ('setting', 96),
#  ('s', 96),
#  ('search', 95),
#  ('dashboard', 95),
#  ('isolator', 95),
#  ('bug', 95),
#  ('end', 95),
#  ('bean', 94),
#  ('talend', 94),
#  ('pc', 93),
#  ('width', 93),
#  ('make', 92),
#  ('tool', 92),
#  ('profile', 92),
#  ('web', 92),
#  ('maven', 92),
#  ('emulator', 92),
#  ('behavior', 91),
#  ('role', 91),
#  ('valid', 91),
#  ('repository', 91),
#  ('design', 91),
#  ('policy', 90),
#  ('second', 90),
#  ('branch', 90),
#  ('ensure', 90),
#  ('improve', 90),
#  ('javascript', 89),
#  ('connect', 89),
#  ('correctly', 89),
#  ('local', 89),
#  ('rule', 89),
#  ('inside', 88),
#  ('copy', 88),
#  ('session', 88),
#  ('credential', 88),
#  ('simple', 87),
#  ('review', 87),
#  ('similar', 87),
#  ('cluster', 87),
#  ('flow', 87),
#  ('place', 86),
#  ('invoke', 86),
#  ('index', 86),
#  ('timeout', 86),
#  ('esb', 85),
#  ('clover', 85),
#  ('height', 85),
#  ('functionality', 85),
#  ('x', 84),
#  ('shell', 84),
#  ('download', 84),
#  ('password', 84),
#  ('sam', 83),
#  ('win', 83),
#  ('convert', 83),
#  ('mean', 83),
#  ('notification', 83),
#  ('regression', 82),
#  ('iphone', 82),
#  ('windows', 82),
#  ('tap', 81),
#  ('disk', 81),
#  ('bind', 81),
#  ('collection', 81),
#  ('switch', 81),
#  ('containerizer', 81),
#  ('performance', 80),
#  ('reason', 80),
#  ('batch', 80),
#  ('know', 80),
#  ('offer', 80),
#  ('timestamp', 80),
#  ('mem', 80),
#  ('leave', 80),
#  ('prompt', 80),
#  ('ok', 80),
#  ('network', 79),
#  ('login', 79),
#  ('header', 79),
#  ('post', 79),
#  ('old', 79),
#  ('activity', 79),
#  ('label', 78),
#  ('m', 78),
#  ('connector', 78),
#  ('corefoundation', 78),
#  ('present', 77),
#  ('enter', 77),
#  ('xcode', 77),
#  ('hdfs', 77),
#  ('argument', 76),
#  ('refer', 76),
#  ('expose', 76),
#  ('global', 76),
#  ('development', 75),
#  ('restart', 75),
#  ('fine', 75),
#  ('alert', 74),
#  ('validation', 74),
#  ('bar', 74),
#  ('integration', 74),
#  ('startup', 74),
#  ('cxf', 74),
#  ('character', 74),
#  ('proxy', 73),
#  ('cgroup', 73),
#  ('append', 73),
#  ('go', 73),
#  ('os', 73),
#  ('perform', 73),
#  ('following', 73),
#  ('well', 73),
#  ('token', 72),
#  ('creation', 72),
#  ('verify', 72),
#  ('think', 72),
#  ('have', 71),
#  ('wrong', 71),
#  ('payload', 71),
#  ('date', 71),
#  ('coverage', 71),
#  ('sprint', 70),
#  ('describe', 70),
#  ('mac', 70),
#  ('quote', 69),
#  ('validate', 69),
#  ('stop', 69),
#  ('guide', 69),
#  ('license', 68),
#  ('processor', 68),
#  ('hide', 68),
#  ('bump', 68),
#  ('phone', 68),
#  ('art', 68),
#  ('wait', 68),
#  ('directly', 68),
#  ('account', 67),
#  ('additional', 67),
#  ('recovery', 67),
#  ('storage', 67),
#  ('competency', 67),
#  ('locate', 67),
#  ('int', 67),
#  ('automatically', 67),
#  ('separate', 67),
#  ('necessary', 67),
#  ('console', 66),
#  ('contact', 66),
#  ('publish', 66),
#  ('bundle', 66),
#  ('public', 66),
#  ('good', 66),
#  ('host', 66),
#  ('c', 65),
#  ('external', 65),
#  ('usergrid', 65),
#  ('kafka', 64),
#  ('usage', 64),
#  ('child', 64),
#  ('certificate', 64),
#  ('uikit', 64),
#  ('terminate', 63),
#  ('bay', 63),
#  ('google', 63),
#  ('june', 63),
#  ('count', 63),
#  ('trigger', 63),
#  ('lead', 63),
#  ('parse', 63),
#  ('upload', 63),
#  ('namespace', 63),
#  ('rd', 63),
#  ('break', 62),
#  ('introduce', 62),
#  ('watch', 62),
#  ('authorization', 62),
#  ('tiapp', 62),
#  ('comment', 62),
#  ('quota', 62),
#  ('solomon', 62),
#  ('mn', 62),
#  ('switzerland', 62),
#  ('channel', 62),
#  ('block', 61),
#  ('retrieve', 61),
#  ('driver', 61),
#  ('initialize', 61),
#  ('extension', 61),
#  ('volume', 61),
#  ('push', 61),
#  ('export', 61),
#  ('relate', 60),
#  ('ability', 60),
#  ('modify', 60),
#  ('easy', 60),
#  ('mobileweb', 60),
#  ('avoid', 59),
#  ('lsst', 59),
#  ('properly', 59),
#  ('language', 59),
#  ('ignore', 59),
#  ('future', 59),
#  ('installation', 59),
#  ('expression', 59),
#  ('row', 59),
#  ('email', 58),
#  ('standard', 58),
#  ('memory', 58),
#  ('deprecate', 58),
#  ('ipad', 58),
#  ('mechanism', 58),
#  ('allocator', 58),
#  ('disable', 57),
#  ('skip', 57),
#  ('story', 57),
#  ('depend', 57),
#  ('repo', 57),
#  ('boot', 57),
#  ('scenario', 57),
#  ('compile', 57),
#  ('zip', 57),
#  ('refactor', 57),
#  ('foo', 57),
#  ('thing', 56),
#  ('limit', 56),
#  ('basic', 56),
#  ('see', 56),
#  ('ssl', 56),
#  ('theme', 56),
#  ('improvement', 56),
#  ('libprocess', 55),
#  ('actually', 55),
#  ('git', 55),
#  ('workspace', 55),
#  ('control', 55),
#  ('rename', 55),
#  ('apple', 55),
#  ('accept', 55),
#  ('distribution', 55),
#  ('builder', 55),
#  ('selection', 55),
#  ('drop', 55),
#  ('curl', 55),
#  ('model', 54),
#  ('previous', 54),
#  ('truncate', 54),
#  ('high', 54),
#  ('acs', 54),
#  ('force', 54),
#  ('pattern', 54),
#  ('jira', 54),
#  ('come', 54),
#  ('duplicate', 53),
#  ('ndk', 53),
#  ('cache', 53),
#  ('tiuiimageview', 53),
#  ('consider', 53),
#  ('affect', 53),
#  ('exit', 53),
#  ('investigate', 53),
#  ('explorer', 52),
#  ('probably', 52),
#  ('artifact', 52),
#  ('nest', 52),
#  ('bamboo', 52),
#  ('persistent', 52),
#  ('username', 52),
#  ('handler', 52),
#  ('machine', 52),
#  ('bytes', 52),
#  ('optional', 52),
#  ('parent', 51),
#  ('processing', 51),
#  ('course', 51),
#  ('style', 51),
#  ('destroy', 51),
#  ('toolbar', 51),
#  ('running', 51),
#  ('solution', 50),
#  ('large', 50),
#  ('bad', 50),
#  ('remote', 50),
#  ('visible', 50),
#  ('remain', 50),
#  ('tag', 50),
#  ('structure', 50),
#  ('indicator', 50),
#  ('bus', 50),
#  ('zookeeper', 50),
#  ('camera', 50),
#  ('rate', 50),
#  ('red', 50),
#  ('site', 50),
#  ('ip', 50),
#  ('installer', 49),
#  ('void', 49),
#  ('operator', 49),
#  ('bit', 49),
#  ('principal', 49),
#  ('logic', 49),
#  ('box', 49),
#  ('let', 48),
#  ('mark', 48),
#  ('classpath', 48),
#  ('browser', 48),
#  ('preview', 48),
#  ('statistic', 48),
#  ('binary', 48),
#  ('listview', 48),
#  ('enum', 48),
#  ('undefined', 48),
#  ('integrate', 47),
#  ('estimate', 47),
#  ('capability', 47),
#  ('clear', 47),
#  ('cleanup', 47),
#  ('production', 47),
#  ('determine', 47),
#  ('background', 47),
#  ('duration', 47),
#  ('record', 47),
#  ('observe', 47),
#  ('cloud', 47),
#  ('cancel', 47),
#  ('jdbc', 47),
#  ('dq', 47),
#  ('geocoder', 46),
#  ('active', 46),
#  ('sql', 46),
#  ('manually', 46),
#  ('pid', 46),
#  ('loading', 46),
#  ('demo', 46),
#  ('auxiliary', 46),
#  ('later', 45),
#  ('html', 45),
#  ('coordinator', 45),
#  ('lock', 45),
#  ('share', 45),
#  ('manager', 45),
#  ('wsdl', 45),
#  ('extend', 45),
#  ('factory', 45),
#  ('char', 45),
#  ('uncaught', 45),
#  ('sdks', 45),
#  ('rabbit', 44),
#  ('layout', 44),
#  ('common', 44),
#  ('counter', 44),
#  ('security', 44),
#  ('refresh', 44),
#  ('static', 44),
#  ('b', 44),
#  ('portal', 44),
#  ('choose', 44),
#  ('callback', 44),
#  ('locator', 44),
#  ('produce', 44),
#  ('useful', 44),
#  ('attachment', 44),
#  ('assignment', 43),
#  ('commit', 43),
#  ('allocate', 43),
#  ('suggest', 43),
#  ('constraint', 43),
#  ('transport', 43),
#  ('python', 43),
#  ('uuid', 43),
#  ('qserv', 43),
#  ('discussion', 42),
#  ('workaround', 42),
#  ('initial', 42),
#  ('move', 42),
#  ('protobuf', 42),
#  ('develop', 42),
#  ('total', 42),
#  ('sync', 42),
#  ('constructor', 42),
#  ('progress', 42),
#  ('disabled', 42),
#  ('white', 41),
#  ('appropriate', 41),
#  ('understand', 41),
#  ('small', 41),
#  ('indicate', 41),
#  ('team', 41),
#  ('redi', 41),
#  ('mysql', 41),
#  ('prevent', 41),
#  ('override', 41),
#  ('core', 41),
#  ('textfield', 40),
#  ('launcher', 40),
#  ('registrar', 40),
#  ('js', 40),
#  ('scroll', 40),
#  ('yes', 40),
#  ('anonfun', 40),
#  ('ask', 40),
#  ('unique', 40),
#  ('manifest', 40),
#  ('spark', 40),
#  ('shutdown', 40),
#  ('soap', 40),
#  ('metric', 40),
#  ('manage', 39),
#  ('loop', 39),
#  ('registration', 39),
#  ('migration', 39),
#  ('controller', 39),
#  ('focus', 39),
#  ('oversubscribed', 38),
#  ('chart', 38),
#  ('perspective', 38),
#  ('analytic', 38),
#  ('yarn', 38),
#  ('promise', 38),
#  ('apis', 38),
#  ('mapping', 38),
#  ('consistent', 38),
#  ('classic', 38),
#  ('socket', 38),
#  ('listener', 38),
#  ('submit', 38),
#  ('arrow', 38),
#  ('unit', 37),
#  ('osgi', 37),
#  ('strategy', 37),
#  ('datasense', 37),
#  ('one', 37),
#  ('incorrect', 37),
#  ('compare', 37),
#  ('assign', 36),
#  ('prefix', 36),
#  ('related', 36),
#  ('domain', 36),
#  ('rebuild', 36),
#  ('difference', 36),
#  ('infrastructure', 36),
#  ('original', 36),
#  ('say', 36),
#  ('jmx', 36),
#  ('syntax', 36),
#  ('sort', 36),
#  ('provision', 36),
#  ('hostname', 36),
#  ('likely', 36),
#  ('uri', 36),
#  ('dalvikvm', 36),
#  ('proposal', 36),
#  ('ubuntu', 35),
#  ('home', 35),
#  ('behaviour', 35),
#  ('filesystem', 35),
#  ('linux', 35),
#  ('encounter', 35),
#  ('eclipse', 34),
#  ('approach', 34),
#  ('requirement', 34),
#  ('aptana', 34),
#  ('t', 34),
#  ('qa', 34),
#  ('dynamic', 34),
#  ('extra', 34),
#  ('continue', 34),
#  ('alias', 34),
#  ('nice', 34),
#  ('authenticator', 34),
#  ('self', 34),
#  ('minor', 34),
#  ('jms', 34),
#  ('proper', 34),
#  ('tac', 33),
#  ('reflect', 33),
#  ('panel', 33),
#  ('embed', 33),
#  ('lookup', 33),
#  ('hit', 33),
#  ('fetch', 33),
#  ('associate', 33),
#  ('video', 33),
#  ('leader', 33),
#  ('liveview', 33),
#  ('logs', 33),
#  ('fff', 33),
#  ('algorithm', 33),
#  ('pull', 33),
#  ('catch', 33),
#  ('prepare', 33),
#  ('rely', 33),
#  ('major', 33),
#  ('checkbox', 32),
#  ('migrate', 32),
#  ('picker', 32),
#  ('partition', 32),
#  ('schema', 32),
#  ('navigate', 32),
#  ('org', 32),
#  ('identify', 32),
#  ('udid', 32),
#  ('measurement', 32),
#  ('fill', 32),
#  ('authorize', 32),
#  ('boolean', 32),
#  ('spi', 31),
#  ('merge', 31),
#  ('capture', 31),
#  ('github', 31),
#  ('stage', 31),
#  ('param', 31),
#  ('sl', 31),
#  ('virtual', 31),
#  ('inform', 31),
#  ('facebook', 31),
#  ('category', 30),
#  ('quick', 30),
#  ('splash', 30),
#  ('reopen', 30),
#  ('dev', 30),
#  ('maintenance', 30),
#  ('estimator', 30),
#  ('assume', 30),
#  ('lot', 30),
#  ('explicitly', 30),
#  ('diagnostic', 30),
#  ('explicit', 30),
#  ('cover', 30),
#  ('product', 30),
#  ('rw', 30),
#  ('maybe', 30),
#  ('recognize', 30),
#  ('apache', 30),
#  ('parser', 30),
#  ('camel', 30),
#  ('general', 30),
#  ('abort', 30),
#  ('statement', 30),
#  ('webview', 30),
#  ('tableview', 30),
#  ('turn', 30),
#  ('pool', 30),
#  ('expand', 30),
#  ('blob', 30),
#  ('revert', 30),
#  ('tizen', 30),
#  ('instrument', 30),
#  ('karaf', 30),
#  ('shortcut', 29),
#  ('packaging', 29),
#  ('purpose', 29),
#  ('popup', 29),
#  ('unexpected', 29),
#  ('schedule', 29),
#  ('freeze', 29),
#  ('people', 29),
#  ('css', 29),
#  ('scope', 29),
#  ('rabbitmq', 29),
#  ('androidruntime', 29),
#  ('allocation', 29),
#  ('play', 29),
#  ('overview', 29),
#  ('font', 29),
#  ('hello', 29),
#  ('idea', 28),
#  ('liveviewer', 28),
#  ('elect', 28),
#  ('week', 28),
#  ('relevant', 28),
#  ('meso', 28),
#  ('patch', 28),
#  ('ideally', 28),
#  ('bpm', 28),
#  ('selector', 28),
#  ('iterate', 28),
#  ('particular', 28),
#  ('customer', 28),
#  ('pop', 28),
#  ('successful', 28),
#  ('keyboard', 28),
#  ('consume', 28),
#  ('perf', 28),
#  ('form', 28),
#  ('deliver', 28),
#  ('cmake', 28),
#  ('recent', 28),
#  ('compiler', 28),
#  ('temporary', 28),
#  ('propose', 28),
#  ('effect', 28),
#  ('annotation', 28),
#  ('addition', 28),
#  ('involve', 28),
#  ('will', 28),
#  ('press', 28),
#  ('cos', 27),
#  ('snapshot', 27),
#  ('concept', 27),
#  ('vfy', 27),
#  ('jun', 27),
#  ('unhandled', 27),
#  ('pane', 27),
#  ('hierarchical', 27),
#  ('kernel', 27),
#  ('distribute', 27),
#  ('writer', 27),
#  ('producer', 27),
#  ('evaluate', 27),
#  ('transform', 27),
#  ('represent', 27),
#  ('kill', 27),
#  ('simply', 27),
#  ('observer', 27),
#  ('history', 26),
#  ('important', 26),
#  ('pipeline', 26),
#  ('hsc', 26),
#  ('activate', 26),
#  ('serve', 26),
#  ('cast', 26),
#  ('forward', 26),
#  ('na', 26),
#  ('range', 26),
#  ('pom', 26),
#  ('reservation', 26),
#  ('restore', 26),
#  ('organization', 26),
#  ('moodle', 26),
#  ('reserve', 26),
#  ('recreate', 25),
#  ('join', 25),
#  ('terminal', 25),
#  ('collect', 25),
#  ('frame', 25),
#  ('compute', 25),
#  ('pick', 25),
#  ('correspond', 25),
#  ('pdf', 25),
#  ('goal', 25),
#  ('recompile', 25),
#  ('private', 25),
#  ('insert', 25),
#  ('quartzcore', 25),
#  ('cpu', 25),
#  ('i', 25),
#  ('pause', 25),
#  ...]

# %%
def vocab_word_features(corpus, vocab):
    feature_dict = defaultdict(int)
    for token in vocab:
        feature_vec = []
        for l in label_names:
            feature_vec.append(cond_freqs[l][token])
        pair = (token, feature_vec)
        feature_dict[token] = feature_vec    
        
    return feature_dict

# %%
vocab_features = vocab_word_features(corpus, vocab)
vocab_features
# Out:
# defaultdict(int,
#             {'screenreader': [0, 0, 1, 2, 2, 1, 0, 1, 0],
#              'functorkey': [3, 5, 2, 0, 0, 0, 0, 0, 0],
#              'mybigjobby': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'ssisession': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'settle': [0, 2, 0, 0, 1, 0, 0, 0, 0],
#              'alloytwocall': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'continuously': [4, 4, 7, 6, 3, 0, 0, 1, 0],
#              'recreate': [10, 3, 25, 13, 9, 4, 0, 0, 0],
#              'parseshort': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'bnsf': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'interfaceoperation': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'jobfactory': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'currentusernotificationsetting': [0, 0, 1, 0, 0, 1, 0, 0, 0],
#              'influence': [3, 0, 7, 1, 2, 1, 0, 0, 0],
#              'poasassignment': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'superclassorinterface': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'isn': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'wcslib': [4, 3, 0, 0, 0, 0, 2, 0, 0],
#              'analsysis': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'movecontent': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'gpl': [0, 0, 2, 3, 4, 0, 0, 0, 0],
#              'parmeter': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'throttling': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'expore': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'continserterhelper': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'motion': [0, 0, 1, 1, 1, 0, 0, 0, 0],
#              'teststub': [0, 0, 3, 0, 0, 0, 0, 0, 0],
#              'service': [525, 414, 468, 377, 185, 43, 6, 8, 4],
#              'lalr': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'invitationcategory': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'gmp': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'competion': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'displayjobexecution': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'replan': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'trust': [5, 1, 8, 1, 0, 0, 0, 0, 0],
#              'ewan': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'applicationcontext': [1, 3, 4, 3, 1, 0, 0, 0, 0],
#              'servname': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'approxorderx': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'developper': [0, 1, 0, 2, 0, 0, 0, 0, 0],
#              'objectclass': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'expiring': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'air': [0, 0, 3, 1, 0, 2, 0, 0, 0],
#              'defaultexpressionmanager': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'maxpoolsize': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'requestmethod': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'trestprovider': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'subobject': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'intermitently': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'source': [427, 309, 452, 450, 322, 80, 21, 6, 1],
#              'setted': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'webfont': [0, 1, 0, 0, 1, 0, 0, 0, 0],
#              'vo': [0, 1, 1, 0, 0, 0, 0, 0, 0],
#              'testfiledescriptorleaks': [2, 2, 0, 0, 0, 0, 0, 0, 0],
#              'rist': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'configurableconversionservice': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'autohide': [0, 0, 2, 2, 0, 2, 0, 0, 0],
#              'govern': [1, 0, 1, 0, 0, 0, 0, 0, 0],
#              'thomas': [0, 0, 1, 1, 1, 0, 0, 0, 0],
#              '網上廣東話輸入法': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'align': [7, 13, 13, 20, 10, 3, 2, 0, 0],
#              'queryid': [2, 0, 1, 0, 0, 0, 0, 0, 0],
#              'dll': [1, 1, 1, 2, 0, 0, 0, 0, 0],
#              'replacecharactersinrange': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'participate': [7, 14, 6, 0, 4, 0, 2, 0, 2],
#              'freedom': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'approproate': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'citizen': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'processmanager': [1, 0, 3, 0, 0, 0, 0, 0, 0],
#              'contextmode': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'clipped': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'introspection': [1, 1, 0, 1, 3, 1, 0, 0, 0],
#              'registring': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'saie': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'testsam': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'madden': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'webviewonload': [0, 0, 0, 0, 3, 0, 0, 0, 0],
#              'hight': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'ext': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'apshttpclient': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'penetration': [0, 0, 0, 0, 0, 0, 0, 2, 0],
#              'savecollectionmember': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'likeley': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'uninherite': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'messagerate': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'getdistancefilter': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'deadlok': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'buildtype': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'attributeproxy': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'modifier': [1, 1, 2, 6, 0, 0, 0, 2, 0],
#              'virtually': [1, 1, 1, 0, 0, 0, 0, 0, 0],
#              'flowplayer': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'iteration': [9, 10, 8, 10, 8, 0, 1, 0, 0],
#              'menubar': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'tortor': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'omission': [1, 0, 0, 2, 0, 0, 0, 0, 0],
#              'nulla': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'unsatisfied': [4, 1, 0, 3, 0, 0, 0, 0, 0],
#              'myfunction': [0, 0, 2, 0, 1, 3, 0, 0, 0],
#              'disparity': [1, 0, 1, 0, 0, 0, 0, 0, 0],
#              'numpy': [19, 9, 2, 1, 0, 0, 0, 0, 0],
#              'richness': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'okhttp': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'usser': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'queuemanager': [2, 2, 2, 0, 0, 0, 0, 0, 0],
#              'intersectiontransitivepagingit': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'searchaschild': [0, 0, 2, 0, 1, 0, 0, 0, 0],
#              'internet': [10, 3, 7, 8, 3, 0, 1, 2, 0],
#              'textfilebuffermanager': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'rdbms': [0, 2, 1, 3, 4, 0, 3, 0, 0],
#              'convinced': [0, 1, 1, 0, 0, 0, 0, 0, 0],
#              'retransmit': [4, 0, 0, 0, 0, 0, 0, 0, 0],
#              'timer': [2, 9, 5, 4, 1, 1, 0, 0, 0],
#              'higher': [1, 0, 1, 0, 0, 0, 1, 0, 0],
#              'vendordependencie': [0, 1, 2, 0, 0, 0, 0, 0, 0],
#              'ribbon': [1, 0, 0, 0, 1, 0, 0, 0, 0],
#              'dictum': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'exploratory': [0, 1, 1, 2, 1, 1, 0, 1, 0],
#              'qas': [1, 1, 0, 0, 4, 2, 0, 0, 0],
#              'fixedspace': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'unmount': [28, 5, 4, 0, 2, 0, 0, 0, 0],
#              'resetzoom': [0, 0, 0, 4, 0, 0, 0, 0, 0],
#              'shapehsm': [5, 1, 0, 0, 0, 0, 0, 0, 0],
#              'twebview': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'nsnumber': [1, 2, 0, 1, 0, 0, 0, 0, 0],
#              'tabular': [0, 1, 1, 1, 0, 0, 0, 1, 0],
#              'onmodelevent': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'titaniumupdaterutil': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'refcnt': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'redrawe': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'screen': [111, 72, 144, 259, 160, 53, 26, 23, 14],
#              'visibly': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'lsstsw': [26, 2, 9, 7, 0, 0, 0, 0, 0],
#              'shortcut': [8, 16, 29, 84, 52, 6, 3, 0, 0],
#              'bhl': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'xcrun': [0, 0, 1, 0, 0, 1, 0, 0, 0],
#              'withín': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'methodology': [1, 1, 0, 0, 2, 1, 0, 0, 0],
#              'vitae': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'qe': [1, 1, 5, 6, 5, 2, 0, 0, 0],
#              'set': [643, 422, 637, 755, 464, 161, 57, 32, 20],
#              'parametrized': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'monochrome': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'fixme': [0, 0, 0, 3, 1, 0, 0, 1, 0],
#              'disrupt': [1, 0, 1, 0, 0, 0, 0, 0, 0],
#              'occasionally': [4, 3, 7, 5, 3, 0, 0, 0, 0],
#              'exploer': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'hte': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'buildexpiryaction': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'outputhandler': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'without': [1, 0, 2, 0, 0, 0, 0, 0, 0],
#              'pervasive': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'boom': [1, 0, 1, 0, 0, 0, 0, 0, 0],
#              'discoverer': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'trail': [12, 1, 2, 8, 5, 5, 0, 2, 0],
#              'testwebview': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'resolvenode': [0, 1, 1, 0, 1, 0, 0, 0, 0],
#              'ruse': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'contrary': [5, 1, 0, 1, 0, 1, 0, 0, 0],
#              'mako': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'aborted': [3, 1, 2, 0, 0, 0, 0, 0, 0],
#              'resourcesrecovere': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'jh': [0, 0, 0, 0, 0, 0, 1, 2, 1],
#              'free': [50, 26, 15, 29, 13, 3, 1, 4, 0],
#              'numofanswer': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'fraud': [0, 0, 2, 0, 0, 2, 0, 0, 0],
#              'defaultmulecontextfactory': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'initializerscript': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'do': [2, 0, 0, 0, 1, 0, 0, 0, 0],
#              'overcome': [1, 1, 2, 0, 1, 1, 0, 0, 0],
#              'createsection': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'methodmetric': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'dotted': [0, 0, 1, 0, 3, 0, 0, 0, 0],
#              'mote': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'contacts': [0, 0, 9, 1, 0, 0, 0, 0, 0],
#              'dqrepositoryview': [0, 0, 0, 1, 0, 0, 1, 0, 0],
#              'ssns': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'ipsource': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'configre': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'safari': [6, 0, 6, 17, 3, 9, 5, 1, 0],
#              'dbconneciton': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'jsx': [0, 1, 0, 0, 1, 0, 0, 0, 0],
#              'chdl': [0, 0, 4, 0, 0, 0, 0, 0, 0],
#              'reduceframe': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'moved': [0, 0, 1, 0, 0, 1, 0, 0, 0],
#              'childevent': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'watchos': [0, 0, 7, 15, 1, 2, 0, 0, 0],
#              'remoe': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'queryreturncheck': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'jsonstringtoobjecttransformertest': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'onboarding': [0, 1, 0, 1, 0, 0, 0, 0, 0],
#              'zeropoint': [0, 1, 0, 0, 7, 0, 0, 0, 0],
#              'serenity': [2, 0, 0, 0, 0, 0, 1, 0, 0],
#              'isindeterminate': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'ptf': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'libarie': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'describesobject': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'addable': [0, 1, 2, 0, 0, 0, 0, 0, 0],
#              'cleanconsumer': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'iphoneonly': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'projectiondocument': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'empedde': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'apidoc': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'mimetypes': [0, 0, 0, 0, 0, 2, 0, 0, 0],
#              'tablet': [0, 0, 6, 17, 2, 4, 0, 0, 1],
#              'archives': [0, 0, 0, 1, 1, 0, 0, 0, 0],
#              'eligible': [12, 0, 3, 1, 0, 0, 0, 0, 0],
#              'mem': [120, 83, 80, 9, 18, 0, 0, 0, 0],
#              'land': [6, 3, 2, 1, 3, 0, 0, 0, 0],
#              'reschedule': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'nslocationalwaysusagedescriptiondeny': [0,
#               0,
#               2,
#               0,
#               0,
#               0,
#               0,
#               0,
#               0],
#              'databaseexist': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'subchunkid': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'jens': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'pushbackinputstream': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'artfiact': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'pollhdfs': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'ami': [19, 10, 9, 10, 1, 0, 0, 0, 0],
#              'authoriz': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'descriptor': [7, 7, 7, 18, 4, 0, 0, 0, 0],
#              'lift': [1, 1, 2, 0, 0, 0, 0, 0, 0],
#              'topic': [20, 9, 23, 26, 7, 6, 1, 0, 2],
#              'usb': [2, 0, 0, 5, 3, 5, 0, 0, 0],
#              'dowloade': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'lchoudharymbp': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'cumulative': [2, 2, 3, 0, 7, 1, 0, 0, 0],
#              'wtmap': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'convallis': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'distinct': [9, 4, 4, 8, 7, 2, 1, 0, 0],
#              'huffer': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'sctm': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'assist': [23, 9, 19, 63, 140, 41, 14, 1, 1],
#              'xpaset': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'selfinvoke': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'interference': [1, 0, 0, 0, 1, 0, 0, 0, 0],
#              'templatemanager': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'commont': [0, 0, 0, 0, 0, 0, 1, 0, 0],
#              'linktime': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'testtapsparkprocessor': [1, 2, 0, 0, 0, 0, 0, 0, 0],
#              'joblet': [0, 5, 3, 0, 0, 0, 0, 0, 0],
#              'queuesession': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'maria': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'activemqcpp': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'finishlayout': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'degrade': [0, 0, 1, 2, 2, 0, 0, 0, 0],
#              'simpleconfigurationbuilder': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'innertest': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'flavor': [6, 6, 7, 1, 0, 0, 0, 0, 0],
#              'dosendline': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'tzolov': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'mogrify': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'redisstreamdeploymentintegrationtest': [1,
#               0,
#               0,
#               0,
#               0,
#               0,
#               0,
#               0,
#               0],
#              'ore': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'unregistration': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'mesoscontainerize': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'offsetstoremaxfetchsize': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'pxe': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'browsercompatibilitytest': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'mcast': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'serviceproxy': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'thing': [40, 47, 56, 68, 62, 31, 14, 10, 4],
#              'wpsdk': [0, 0, 0, 2, 9, 0, 0, 0, 0],
#              'directo': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'folowe': [0, 0, 0, 0, 1, 1, 0, 0, 0],
#              'ccrecipient': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'doproxydelegaterea': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'parserpool': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'camelcase': [1, 0, 2, 0, 2, 0, 0, 0, 0],
#              'clone': [27, 20, 13, 25, 11, 11, 0, 0, 0],
#              'membership': [3, 0, 3, 6, 0, 1, 0, 0, 0],
#              'getshowcalibration': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'rcp': [4, 0, 0, 4, 15, 3, 0, 0, 0],
#              'jmxenable': [0, 1, 1, 0, 0, 0, 0, 0, 0],
#              'ticket': [101, 87, 99, 154, 84, 26, 2, 0, 1],
#              'deistribution': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'trimtosize': [0, 0, 0, 0, 4, 0, 0, 0, 0],
#              'shoule': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'rationalize': [1, 2, 1, 0, 0, 0, 0, 0, 0],
#              'excepiton': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'backlogge': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'unnamed': [0, 0, 3, 0, 0, 0, 0, 0, 0],
#              'restricition': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'fiducial': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'decently': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'gridcolumns': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'simplemessagelistenercontainer': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'exploit': [0, 0, 0, 1, 2, 0, 0, 0, 0],
#              'loudly': [1, 1, 0, 0, 0, 0, 0, 0, 0],
#              'anslysis': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'prepareforbuild': [0, 0, 1, 1, 0, 0, 0, 0, 0],
#              'noble': [0, 0, 6, 0, 0, 0, 0, 0, 0],
#              'versione': [3, 4, 5, 1, 2, 0, 0, 0, 0],
#              'whiltelist': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'streamx': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'microphone': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'unobvious': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'idattribute': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'capacity': [3, 1, 8, 5, 5, 1, 0, 0, 1],
#              'transactionattribute': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'findtargetmethod': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'connectionfactory': [0, 3, 0, 0, 1, 0, 0, 0, 0],
#              'barbara': [0, 0, 0, 1, 1, 0, 1, 0, 1],
#              'leadership': [9, 3, 3, 2, 0, 0, 0, 0, 0],
#              'kmditemkind': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'hackathon': [2, 16, 0, 0, 0, 0, 0, 0, 0],
#              'unschedule': [0, 0, 1, 2, 1, 0, 0, 0, 0],
#              'confirmationrequire': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'indented': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'cnt': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'commercial': [3, 1, 4, 1, 0, 0, 0, 0, 0],
#              'proxy': [46, 27, 73, 112, 100, 21, 0, 0, 0],
#              'actiongroup': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'podfile': [0, 0, 1, 1, 0, 0, 0, 0, 0],
#              'rr': [1, 0, 2, 0, 0, 0, 0, 0, 0],
#              'controll': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'potrait': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'bewilder': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'embeddedcontainer': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'generatedsymfile': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'deploysettingshandler': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'translating': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'exists': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'trough': [1, 0, 0, 1, 0, 0, 0, 0, 0],
#              'jdbcmessagepayloadtransformer': [3, 1, 1, 0, 0, 0, 0, 0, 0],
#              'getallbuildparticipant': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'setview': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'csetbody': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'getdefault': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'largeicon': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'throwable': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'distribution': [43, 27, 55, 85, 51, 7, 2, 0, 5],
#              'inverseoffers': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'animatebox': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'cabinet': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'indexbuildparticipant': [0, 0, 0, 0, 1, 0, 0, 1, 0],
#              'headerview': [0, 0, 4, 19, 1, 0, 0, 0, 0],
#              'registerforpushnotification': [0, 0, 0, 0, 3, 0, 0, 0, 0],
#              'breaked': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'getaddress': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'science': [6, 5, 6, 5, 2, 0, 3, 0, 2],
#              'cloudformation': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'freeaddrinfo': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'characterization': [3, 0, 0, 1, 0, 0, 3, 0, 1],
#              'center': [18, 23, 20, 26, 17, 2, 0, 0, 0],
#              'configurationexception': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'apc': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'holding': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'trivially': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'contenthash': [0, 0, 0, 0, 0, 1, 1, 0, 0],
#              'suppresswarning': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'invokation': [0, 0, 0, 0, 0, 0, 2, 0, 0],
#              'csrf': [0, 3, 0, 0, 0, 0, 0, 0, 0],
#              'myvar': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'deserializationpostinitialisable': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'reprository': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'sucessfully': [0, 1, 2, 0, 1, 0, 0, 0, 0],
#              'navigationwindow': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'nsf': [3, 1, 1, 1, 0, 0, 0, 0, 0],
#              'tnaivebayesmodel': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'drfsorter': [0, 4, 0, 1, 0, 0, 0, 0, 0],
#              'dard': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'upper': [3, 5, 0, 8, 3, 0, 0, 1, 0],
#              'relate': [64, 46, 60, 77, 74, 28, 20, 14, 5],
#              'suppor': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'fittansipwcstask': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'assignment': [12, 11, 43, 13, 67, 13, 37, 35, 3],
#              'checkavailability': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'connectiontimeout': [0, 1, 2, 0, 0, 0, 0, 0, 0],
#              'subsubsubsection': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'nothe': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'serializationutil': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'removehandler': [0, 0, 3, 0, 0, 0, 0, 0, 0],
#              'webapplicationexception': [2, 1, 1, 0, 0, 0, 0, 0, 0],
#              'stdclas': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'controlledvalidatio': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'presumably': [3, 5, 5, 3, 5, 1, 0, 2, 0],
#              'zeromq': [1, 0, 0, 2, 0, 0, 0, 0, 0],
#              'intelligence': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'visually': [2, 3, 6, 2, 5, 1, 0, 0, 0],
#              'innerlabel': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'stoppable': [1, 0, 2, 0, 0, 0, 0, 0, 0],
#              'defaultfile': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'essentially': [6, 3, 7, 5, 5, 0, 0, 0, 0],
#              'independently': [2, 3, 6, 3, 1, 3, 2, 0, 0],
#              'seletecd': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'boxnet': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'gae': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'sdrp': [0, 2, 1, 0, 0, 0, 0, 0, 0],
#              'overlayfs': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'xf': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'rack': [0, 8, 6, 4, 0, 0, 0, 0, 0],
#              'logline': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'boe': [20, 0, 8, 0, 0, 0, 0, 0, 0],
#              'doclear': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'ld': [2, 0, 3, 6, 4, 0, 0, 0, 0],
#              'overcommit': [1, 1, 5, 0, 3, 0, 0, 0, 0],
#              'serverurl': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'sconsflag': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'docker': [68, 79, 121, 70, 34, 3, 0, 0, 0],
#              'rediscounterrepository': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'entail': [0, 1, 1, 2, 1, 0, 0, 0, 0],
#              'blankπ': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'multicasting': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'viewc': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'arraywithcapacity': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'replytoparameterprocessor': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'dmlc': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'containskey': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'jdbdhdfs': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'cloverreportmojo': [1, 1, 0, 0, 0, 0, 0, 0, 0],
#              'simultaneously': [6, 1, 8, 2, 2, 0, 0, 2, 2],
#              'samenamedifferenttable': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'nsinvalidargumentexception': [2, 2, 5, 1, 0, 0, 0, 0, 0],
#              'roadmap': [1, 3, 1, 0, 0, 0, 0, 0, 0],
#              'irregularity': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'borderwidth': [0, 5, 9, 11, 2, 9, 0, 0, 0],
#              'consul': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'getslotfrombufferlocke': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'epo': [1, 2, 0, 0, 0, 0, 0, 0, 0],
#              'imagedifferencetask': [3, 0, 0, 0, 1, 0, 0, 0, 0],
#              'conversation': [3, 3, 2, 2, 0, 0, 0, 0, 0],
#              'disabletransporttransformer': [0, 0, 0, 0, 3, 0, 0, 0, 0],
#              'bundleelementsconstructor': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'identical': [11, 10, 5, 9, 13, 2, 2, 0, 1],
#              'ifndef': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'ge': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'all': [1, 2, 0, 1, 1, 0, 0, 0, 0],
#              'querybuidler': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'resourceidentifier': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'keen': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'editpdf': [1, 2, 1, 2, 4, 2, 1, 0, 0],
#              'wb': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'pbis': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'bide': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'resultblock': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'retrieve': [51, 39, 61, 70, 31, 20, 3, 0, 0],
#              'iparsenode': [0, 0, 0, 0, 0, 2, 0, 0, 0],
#              'gsu': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'appender': [2, 3, 1, 0, 0, 0, 0, 0, 0],
#              'eureka': [0, 4, 2, 2, 0, 0, 0, 0, 0],
#              'warp': [1, 0, 0, 0, 1, 0, 0, 0, 0],
#              'threadvisibilitystrategy': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'officer': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'ibeam': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'line': [467, 320, 313, 440, 395, 154, 43, 11, 1],
#              'refactore': [6, 8, 15, 18, 15, 3, 1, 0, 3],
#              'indicatorevaluationmain': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'php': [17, 18, 9, 88, 81, 53, 35, 3, 2],
#              'growth': [0, 0, 0, 1, 1, 0, 0, 0, 0],
#              'updatesourcecoord': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'managementserviceimpl': [0, 1, 2, 0, 0, 0, 0, 0, 0],
#              'rabbitconnectionfactorybean': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'million': [1, 3, 1, 6, 2, 0, 0, 0, 0],
#              'lube': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'queuechannel': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'regroup': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'nonrevocable': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'testdefaults': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'definitation': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'kit': [0, 0, 2, 7, 0, 0, 0, 0, 0],
#              'lazyinitializer': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'pixelmargin': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'filestatus': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'peration': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'nutbar': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'infomation': [1, 0, 1, 0, 0, 0, 0, 0, 0],
#              'conserve': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'bayesian': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'сerrorcatcher': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'sfcd': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'jsv': [0, 0, 1, 1, 0, 0, 0, 0, 0],
#              'voiceover': [0, 0, 2, 0, 3, 0, 0, 2, 0],
#              'eventtargetrec': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'pg': [0, 0, 0, 0, 0, 0, 1, 0, 0],
#              'frameworksorter': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'maecenas': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'itemscontrol': [0, 0, 0, 0, 0, 3, 0, 0, 0],
#              'luigi': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'answer': [11, 34, 17, 26, 17, 10, 1, 0, 1],
#              'jbchartview': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'authorcreatorservice': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'seamlessly': [0, 0, 0, 4, 2, 0, 0, 0, 0],
#              'matcheswin': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'tch': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'pollhdf': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'topology': [0, 2, 1, 2, 2, 0, 0, 0, 0],
#              'hoechste': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'eventtype': [3, 0, 4, 1, 0, 0, 0, 0, 0],
#              'eas': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'ins': [1, 0, 0, 0, 1, 0, 0, 0, 0],
#              'htmlpage': [0, 0, 0, 4, 0, 0, 0, 0, 0],
#              'navbarcollapsedesktopwidth': [5, 0, 0, 0, 0, 0, 0, 0, 0],
#              'indicative': [1, 1, 0, 0, 1, 0, 0, 0, 0],
#              'macro': [15, 17, 0, 5, 1, 3, 4, 0, 0],
#              'specical': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'viewagent': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'typecode': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'busetty': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'camerageom': [1, 5, 1, 0, 0, 0, 0, 0, 0],
#              'boundary': [6, 6, 3, 3, 5, 2, 0, 0, 0],
#              'predefined': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'myreview': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'queryclipboard': [0, 0, 0, 0, 3, 0, 0, 0, 0],
#              'rubbly': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'userids': [0, 0, 0, 0, 3, 0, 0, 0, 0],
#              'widthcontrol': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'mechanism': [94, 82, 58, 34, 57, 14, 6, 1, 0],
#              'moduleutil': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'filepath': [2, 2, 1, 2, 0, 0, 1, 0, 0],
#              'canevas': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'httpinboundbasicauth': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'depart': [0, 3, 0, 2, 1, 0, 0, 0, 0],
#              'determinemoduleclass': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'autoboxe': [0, 0, 0, 0, 0, 2, 0, 0, 0],
#              'zo': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'natalie': [0, 0, 0, 3, 1, 0, 0, 0, 0],
#              'mel': [5, 1, 6, 19, 8, 3, 0, 0, 0],
#              'keytable': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'referenced': [4, 1, 5, 2, 4, 2, 1, 0, 0],
#              'serer': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'seach': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'defaultservletmodulemanager': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'nsnotification': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'immutability': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'tci': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'editsection': [0, 0, 0, 0, 0, 0, 1, 0, 0],
#              'zuora': [0, 0, 3, 1, 0, 0, 0, 0, 0],
#              'contextualize': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'artoo': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'commandlinetask': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'serializer': [2, 2, 5, 3, 3, 0, 0, 0, 0],
#              'distractor': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'ssltest': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'cajunspice': [0, 0, 0, 0, 6, 0, 0, 0, 0],
#              'backgroundselectedcolor': [0, 1, 2, 0, 0, 0, 0, 0, 0],
#              'archivejob': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'mvcc': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'restmoduletype': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'offer': [107, 93, 80, 42, 48, 13, 1, 1, 0],
#              'clientip': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'definecentroid': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'originalpagewidth': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'defaultmulecontext': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'nova': [3, 6, 1, 2, 0, 0, 0, 0, 0],
#              'lodge': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'rinse': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'issue': [380, 374, 542, 644, 453, 165, 51, 32, 24],
#              'facility': [3, 2, 2, 1, 3, 2, 1, 1, 1],
#              'demaskate': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'functionaltestcase': [4, 0, 0, 0, 4, 0, 0, 0, 0],
#              'libs': [3, 4, 4, 11, 2, 0, 0, 0, 0],
#              'organizational': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'hoard': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'tiutils': [2, 0, 0, 0, 1, 0, 0, 0, 0],
#              'pragmatically': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'visualstudio': [0, 0, 2, 2, 1, 0, 0, 0, 0],
#              'correspond': [24, 14, 25, 23, 24, 12, 1, 1, 0],
#              'ctabfolderrenderer': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'fudge': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'generic': [26, 10, 24, 22, 28, 12, 2, 1, 0],
#              'applie': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'rubric': [0, 0, 0, 0, 3, 0, 1, 0, 2],
#              'freze': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'spile': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'kiler': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'measureapcorrtask': [2, 0, 0, 0, 1, 0, 0, 0, 0],
#              'processdefinitionuuid': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'consectetaur': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'times': [1, 0, 1, 1, 0, 0, 0, 0, 0],
#              'devolve': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'uistackview': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'jobname': [4, 2, 0, 3, 0, 0, 0, 0, 0],
#              'unzip': [7, 3, 13, 11, 7, 1, 0, 0, 0],
#              'bootstrappe': [1, 1, 2, 2, 5, 3, 0, 0, 0],
#              'jelly': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'setalpha': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'consumerjobs': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'resubmit': [1, 0, 1, 0, 1, 0, 0, 0, 0],
#              'taskproviderfactoryimpl': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'bulkmode': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'limits': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'verifyondemandqueues': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'clonable': [0, 0, 0, 0, 0, 0, 1, 0, 0],
#              'retrie': [8, 9, 4, 5, 0, 0, 0, 0, 0],
#              'fromaddress': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'tojsontablerequest': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'possibilite': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'openwindowonstack': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'assign': [36, 46, 36, 29, 21, 20, 21, 14, 2],
#              'appendinclude': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'loglevelconf': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'panopticon': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'deployedmodulemap': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'notes': [2, 2, 3, 1, 4, 1, 0, 0, 0],
#              'wo': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'didregisterusernotificationsetting': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'shlvl': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'dictate': [2, 0, 0, 3, 1, 0, 0, 0, 0],
#              'beginning': [30, 22, 21, 11, 6, 5, 3, 0, 0],
#              'challenge': [4, 4, 3, 2, 5, 1, 0, 2, 2],
#              'queryreturncheckwithshorthand': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'currentlocale': [0, 4, 0, 1, 0, 0, 0, 0, 0],
#              'outputpath': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'attributes': [1, 0, 2, 1, 1, 0, 0, 0, 0],
#              'accurate': [2, 2, 5, 10, 1, 1, 0, 1, 0],
#              'mvc': [0, 1, 1, 9, 2, 0, 0, 0, 0],
#              'frequently': [7, 5, 2, 5, 4, 2, 0, 1, 0],
#              'textual': [0, 1, 1, 0, 2, 1, 0, 0, 0],
#              'imagemetadata': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'collsns': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'singleframemeasurement': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'abstractfoldingeditor': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'mrefc': [0, 0, 0, 0, 0, 0, 1, 0, 0],
#              'presently': [5, 4, 1, 0, 0, 0, 1, 0, 2],
#              'poc': [1, 1, 5, 13, 13, 1, 0, 0, 2],
#              'propagatevisitflag': [1, 2, 0, 0, 0, 0, 0, 0, 0],
#              'tiappmodel': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'docgen': [0, 5, 0, 3, 0, 0, 0, 0, 0],
#              'tvalidrow': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'decimation': [0, 0, 1, 2, 0, 0, 0, 0, 0],
#              'memorypoolmxbean': [4, 0, 0, 0, 0, 0, 0, 0, 0],
#              'eclipse': [52, 21, 34, 55, 88, 42, 6, 6, 0],
#              'channelpipeline': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'logcustomevent': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'specialize': [0, 1, 0, 0, 1, 0, 0, 0, 0],
#              'defaultexception': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'liner': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'paramsobj': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'cloudfoundryapplication': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'inputpath': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'adherence': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'springboard': [0, 0, 0, 0, 5, 0, 0, 0, 0],
#              'testcontainerizer': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'coveragerecorder': [0, 2, 4, 1, 0, 0, 0, 0, 0],
#              'heterogeneity': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'oj': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'sysdig': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'capitol': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'jpa': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'responsetext': [0, 0, 1, 4, 1, 0, 0, 0, 0],
#              'drafts': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'forceformat': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'dac': [1, 1, 0, 0, 0, 0, 0, 2, 1],
#              'duraadmin': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'trend': [0, 0, 0, 3, 1, 0, 0, 0, 1],
#              'fitsread': [1, 2, 2, 0, 0, 0, 0, 0, 0],
#              'handlesnative': [0, 0, 0, 1, 1, 1, 0, 0, 0],
#              'el': [9, 7, 4, 2, 4, 2, 0, 0, 0],
#              'reboot': [2, 3, 2, 4, 9, 1, 0, 0, 0],
#              'killtaskmessage': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'hdus': [1, 0, 1, 0, 0, 0, 0, 0, 0],
#              'appendbutton': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'glow': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'substitute': [0, 0, 0, 1, 1, 1, 1, 0, 0],
#              'clicklistener': [0, 0, 0, 4, 0, 0, 0, 0, 0],
#              'rootroot': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'demangle': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'dockercontainerizerprocess': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'alll': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'stefan': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'instantiate': [13, 1, 17, 26, 11, 5, 2, 0, 0],
#              'exportable': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'dbg': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'serialise': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'seed': [1, 1, 0, 2, 4, 0, 2, 0, 0],
#              'siging': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'appropriate': [36, 30, 41, 40, 30, 10, 5, 2, 7],
#              'standardengineval': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'stitch': [1, 0, 4, 0, 1, 0, 0, 0, 0],
#              'retieve': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'ecliptic': [1, 2, 0, 0, 0, 0, 0, 0, 0],
#              'checkpointresourcesmessage': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'scrolled': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'downloadfile': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'model': [34, 36, 54, 77, 63, 28, 10, 8, 1],
#              'baseclass': [0, 0, 0, 0, 0, 3, 0, 0, 0],
#              'yarnmoduledeployer': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'fastutil': [0, 0, 1, 0, 1, 0, 0, 0, 0],
#              'uiuc': [0, 9, 0, 0, 0, 0, 0, 0, 0],
#              'admob': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'makechunkandoverlaptable': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'numdiff': [0, 3, 0, 0, 0, 0, 0, 2, 0],
#              'violation': [1, 6, 11, 5, 7, 1, 14, 1, 0],
#              'lhn': [0, 1, 1, 0, 0, 0, 0, 0, 0],
#              'keydispatchingtimedout': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'contentoffset': [0, 0, 3, 1, 1, 0, 0, 0, 0],
#              'abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyz': [0,
#               0,
#               0,
#               0,
#               1,
#               0,
#               0,
#               0,
#               0],
#              'jmxport': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'cardinality': [0, 0, 0, 1, 3, 0, 0, 0, 0],
#              'cody': [0, 1, 1, 0, 0, 0, 0, 0, 0],
#              'trusted': [0, 1, 0, 1, 0, 0, 0, 0, 0],
#              'tostringtransformer': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'retain': [9, 5, 3, 23, 12, 5, 1, 1, 0],
#              'demonstraing': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'rundown': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'lower': [1, 3, 22, 3, 0, 0, 0, 0, 0],
#              'tutorial': [10, 14, 6, 4, 3, 1, 1, 0, 0],
#              'reclassify': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'colon': [5, 1, 3, 6, 2, 1, 0, 0, 0],
#              'setremotebackup': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'featue': [0, 1, 0, 0, 0, 1, 0, 0, 0],
#              'unity': [0, 0, 0, 0, 5, 3, 0, 0, 0],
#              'reregisterslave': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'brainstorming': [0, 0, 0, 0, 0, 0, 0, 0, 1],
#              'pricedescription': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'lastupdate': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'beta': [6, 8, 14, 30, 30, 5, 1, 0, 0],
#              'xsds': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'adrian': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'sampe': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'jogs': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'interop': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'nsis': [0, 0, 0, 0, 1, 1, 0, 0, 0],
#              'newsection': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'httpmethodbase': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'haderror': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'prefix': [42, 27, 36, 85, 6, 4, 1, 1, 0],
#              'audittask': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'doco': [2, 3, 2, 0, 0, 0, 0, 0, 0],
#              'characteristic': [0, 1, 3, 1, 5, 0, 0, 0, 0],
#              'handheld': [1, 0, 0, 3, 0, 0, 0, 0, 0],
#              'isinstance': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'bitronix': [0, 0, 0, 1, 1, 2, 0, 0, 0],
#              'becasue': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'useability': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'initial': [43, 38, 42, 52, 25, 11, 13, 1, 1],
#              'cu': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'amenable': [0, 0, 0, 1, 2, 0, 0, 0, 0],
#              'garble': [0, 1, 0, 1, 0, 0, 0, 0, 0],
#              'snsqueuemanagerimpl': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'nosuchregistryexception': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'cr': [3, 1, 3, 0, 0, 0, 0, 0, 0],
#              'gpfdist': [2, 4, 0, 1, 5, 0, 0, 0, 0],
#              'assets': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'inputfields': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'maintenance': [6, 5, 30, 27, 30, 20, 0, 0, 0],
#              'flag': [175, 131, 154, 83, 47, 6, 2, 2, 3],
#              'top': [0, 0, 6, 1, 1, 3, 0, 0, 0],
#              'getcontentpropertie': [1, 1, 0, 0, 0, 0, 0, 0, 0],
#              'processcoadd': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'bodypart': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'querycontext': [0, 0, 2, 0, 4, 0, 0, 0, 0],
#              'blackboard': [0, 0, 0, 0, 0, 0, 0, 0, 1],
#              'eventkit': [0, 0, 1, 0, 1, 2, 0, 0, 0],
#              'currentwifiname': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'accenture': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'deterministic': [0, 1, 1, 0, 2, 0, 0, 0, 0],
#              'uiapplicationshortcutitemtype': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'parenthesize': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'rtmp': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'defaultchangedetectionmanager': [0, 4, 0, 0, 0, 0, 0, 0, 0],
#              'hdfgroup': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'prepackaged': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'mimi': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'geturi': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'intervalset': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'remae': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'partitioned': [1, 0, 2, 4, 6, 0, 0, 0, 0],
#              'nookcolor': [0, 0, 6, 0, 0, 0, 0, 0, 0],
#              'configurablefield': [1, 1, 1, 0, 0, 0, 0, 0, 0],
#              'hscmapper': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'greedily': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'believe': [21, 14, 22, 23, 19, 7, 0, 1, 0],
#              'mi': [1, 2, 0, 1, 0, 0, 0, 0, 0],
#              'versio': [1, 0, 0, 1, 0, 0, 0, 0, 0],
#              'evans': [0, 0, 0, 0, 0, 0, 1, 0, 0],
#              'except': [0, 0, 1, 0, 0, 0, 1, 0, 0],
#              'mutator': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'rectangular': [0, 2, 0, 0, 1, 0, 0, 0, 0],
#              'replaced': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'lust': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'whatch': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'cookies': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'sun': [2, 3, 1, 4, 8, 0, 0, 0, 0],
#              'beanclassloaderaware': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'xy': [0, 5, 0, 1, 4, 0, 0, 2, 0],
#              'ut': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'colortable': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'webhdfs': [0, 0, 3, 1, 0, 0, 0, 0, 0],
#              'rally': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'pl': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'debugtoken': [0, 0, 0, 4, 0, 0, 0, 0, 0],
#              'pronounce': [0, 0, 0, 0, 0, 0, 0, 0, 1],
#              'itc': [3, 0, 0, 0, 1, 0, 0, 0, 0],
#              'consult': [1, 1, 3, 1, 4, 2, 0, 0, 0],
#              'tpostgresqlinvalidrow': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'mathce': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'resourceconfiguredmodule': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'optimised': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'instrumentation': [19, 7, 9, 12, 6, 10, 6, 4, 0],
#              'less': [0, 0, 0, 1, 2, 1, 0, 0, 0],
#              'implementtion': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'lalo': [0, 0, 0, 5, 0, 3, 0, 0, 0],
#              'backgroundnotification': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'cidempotentconsumer': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'whdfd': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'logmessage': [0, 0, 0, 0, 0, 0, 0, 9, 0],
#              'participant': [5, 2, 3, 0, 10, 5, 4, 4, 0],
#              'false': [264, 288, 233, 161, 99, 19, 4, 11, 0],
#              'messages': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'httprequestauthtestcase': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'android': [155, 168, 780, 1113, 589, 180, 22, 6, 0],
#              'feel': [8, 4, 7, 9, 10, 3, 3, 1, 2],
#              'performsearchfunction': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'bios': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'sensitive': [6, 2, 7, 2, 0, 3, 0, 2, 0],
#              'centers': [1, 1, 0, 0, 0, 0, 0, 0, 0],
#              'formate': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'responsetimeout': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'parseexception': [1, 0, 1, 0, 0, 0, 0, 0, 0],
#              'headway': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'questionable': [1, 1, 1, 0, 1, 0, 0, 0, 0],
#              'abstractmodulefixture': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'argumentparser': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'reporttask': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'epr': [0, 0, 2, 2, 0, 0, 0, 0, 0],
#              'interfacecontroller': [0, 0, 0, 1, 2, 0, 0, 0, 0],
#              'denver': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'outbound': [7, 9, 15, 14, 49, 8, 0, 0, 0],
#              'palce': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'reconvert': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'bisect': [1, 8, 0, 0, 1, 0, 0, 0, 0],
#              'slate': [3, 1, 2, 0, 0, 0, 1, 0, 0],
#              'smartphone': [0, 0, 0, 1, 0, 0, 0, 1, 0],
#              'megastore': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'orci': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'terminating': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'alldata': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'managementresource': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'refert': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'proweb': [0, 1, 0, 0, 1, 0, 0, 0, 0],
#              'iaculis': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'iph': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'assertcount': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'allen': [0, 0, 0, 1, 2, 0, 0, 0, 0],
#              'efefef': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'preface': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'jsl': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'pruned': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'screenx': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'runningo': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'analysistypenode': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'intricacy': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'binname': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'monitored': [0, 0, 1, 1, 0, 0, 0, 0, 0],
#              'jscafileindexingparticipant': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'ndb': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'textfield': [16, 1, 40, 42, 27, 12, 0, 0, 0],
#              'clientside': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'anonymously': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'schedulerprocess': [0, 0, 3, 0, 0, 0, 0, 0, 0],
#              'mineo': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'indexer': [0, 0, 0, 0, 2, 0, 1, 0, 0],
#              'chdir': [0, 0, 1, 0, 3, 0, 0, 0, 0],
#              'nexteventmatchingeventmask': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'ha': [2, 3, 15, 6, 2, 0, 0, 0, 0],
#              'installs': [0, 0, 0, 0, 1, 1, 0, 0, 0],
#              'imagef': [2, 1, 0, 0, 0, 0, 0, 0, 0],
#              'selectionset': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'lastrow': [2, 2, 0, 0, 0, 0, 0, 0, 0],
#              'undersamplestyle': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'isp': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'uuuu': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'createcard': [0, 0, 0, 0, 5, 0, 0, 0, 0],
#              'onclick': [0, 0, 4, 11, 2, 1, 0, 0, 0],
#              'diacritical': [0, 0, 3, 0, 0, 0, 0, 0, 0],
#              'sso': [1, 1, 14, 3, 0, 0, 0, 0, 0],
#              'columntime': [0, 0, 0, 0, 8, 0, 0, 0, 0],
#              'iprogressmonitor': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'realistic': [0, 1, 1, 1, 1, 0, 1, 1, 0],
#              'propertiesresourceit': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'audiance': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'datatip': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'inactivity': [1, 3, 1, 0, 1, 0, 0, 0, 0],
#              'datadirectory': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'dec': [7, 2, 4, 4, 11, 6, 0, 0, 0],
#              'filefinal': [0, 0, 0, 0, 0, 0, 0, 1, 0],
#              'prescribe': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'recompile': [0, 2, 25, 4, 3, 1, 0, 0, 0],
#              'purging': [0, 3, 0, 1, 0, 1, 0, 0, 0],
#              'compositemodule': [1, 0, 0, 2, 0, 0, 0, 0, 0],
#              'identically': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'snapshotlocation': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'performance': [34, 19, 80, 89, 100, 24, 16, 5, 6],
#              'abstractdatacleaner': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'elaboration': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'wefel': [0, 0, 0, 0, 0, 1, 2, 0, 1],
#              'tmachgroup': [0, 0, 1, 0, 0, 1, 0, 0, 0],
#              'export': [78, 119, 61, 85, 33, 24, 21, 12, 2],
#              'hscpipebase': [0, 0, 1, 0, 1, 0, 0, 0, 0],
#              'bridget': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'probably': [62, 46, 52, 66, 49, 23, 8, 7, 1],
#              'bindbackend': [8, 1, 5, 0, 0, 0, 0, 0, 0],
#              'linuxrootfs': [0, 0, 0, 0, 0, 2, 0, 0, 0],
#              'javascript': [41, 39, 89, 147, 176, 47, 17, 21, 10],
#              'insensitive': [0, 0, 3, 2, 0, 0, 0, 0, 0],
#              'putative': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'hsqlserverbean': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'san': [0, 1, 1, 3, 3, 1, 1, 0, 0],
#              'prying': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'balancing': [0, 1, 0, 2, 0, 0, 0, 0, 0],
#              'reviewboard': [0, 1, 1, 0, 0, 1, 0, 0, 0],
#              'put': [13, 12, 11, 17, 7, 1, 4, 1, 1],
#              'agenda': [4, 0, 0, 1, 0, 0, 0, 0, 0],
#              'hitting': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'pr': [14, 8, 24, 45, 20, 5, 0, 0, 0],
#              'seect': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'queryresource': [2, 1, 0, 0, 0, 0, 0, 0, 0],
#              'satellite': [1, 0, 1, 3, 0, 0, 0, 0, 0],
#              'operationimplementation': [0, 0, 0, 0, 1, 1, 0, 0, 0],
#              'filesystemfactorybean': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'qservdata': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'follwoing': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'taskexecutor': [1, 0, 1, 0, 0, 0, 0, 0, 0],
#              'coherently': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'attributeerror': [8, 3, 1, 2, 2, 0, 0, 0, 0],
#              'angle': [1, 5, 0, 0, 0, 1, 0, 0, 0],
#              'digging': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'scriptdoc': [0, 1, 0, 0, 3, 7, 0, 0, 0],
#              'imageview': [0, 11, 20, 29, 27, 7, 0, 0, 0],
#              'tcl': [0, 2, 0, 0, 0, 0, 0, 0, 0],
#              'examine': [3, 4, 5, 9, 6, 4, 1, 1, 0],
#              'muras': [0, 0, 0, 0, 0, 0, 1, 0, 0],
#              'autoreconnect': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'bounce': [3, 0, 1, 4, 2, 0, 0, 0, 0],
#              'cdhash': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'correia': [0, 0, 0, 42, 0, 0, 0, 0, 0],
#              'launcher': [6, 22, 40, 14, 18, 6, 0, 0, 0],
#              'beachball': [0, 0, 0, 0, 2, 0, 0, 0, 0],
#              'express': [4, 2, 8, 4, 4, 2, 0, 0, 0],
#              'eventhis': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'ticli': [0, 0, 0, 3, 0, 0, 0, 0, 0],
#              'unmounte': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'resizeimageforupload': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'shift': [4, 4, 3, 21, 9, 5, 5, 1, 0],
#              'filesink': [0, 0, 3, 4, 0, 0, 0, 0, 0],
#              'nikolay': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'poodle': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'onunaccepte': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              'passphrase': [4, 1, 0, 0, 1, 0, 0, 0, 0],
#              'servername': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'useknownwcs': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'notation': [3, 0, 2, 6, 4, 0, 0, 6, 0],
#              'attach': [173, 108, 249, 319, 256, 70, 18, 1, 0],
#              'ralf': [0, 0, 0, 0, 0, 1, 0, 1, 0],
#              'chilean': [1, 1, 2, 0, 0, 0, 2, 1, 0],
#              'streambuttonclick': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'xdadmin': [3, 0, 0, 0, 1, 0, 0, 0, 0],
#              'predictable': [1, 0, 0, 1, 0, 0, 0, 0, 0],
#              'passthrough': [0, 1, 0, 1, 0, 0, 0, 0, 0],
#              'deactivateframeworkmessage': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'intercept': [8, 0, 6, 14, 0, 0, 1, 3, 0],
#              'ctr': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'tiger': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'mobilewebonly': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'butlerutil': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'htmlbuttonelement': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'appicon': [0, 0, 0, 0, 5, 0, 0, 0, 0],
#              'tabbedview': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'nsuseractivitytypebrowsingweb': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'codepattern': [0, 0, 0, 0, 0, 1, 0, 0, 0],
#              'suspend': [0, 0, 3, 4, 14, 0, 0, 1, 0],
#              'flagdefinition': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'doctype': [0, 1, 0, 0, 3, 0, 0, 0, 0],
#              'mdaddr': [0, 0, 0, 1, 0, 0, 0, 0, 0],
#              'insulate': [0, 1, 1, 0, 1, 0, 0, 0, 0],
#              'domainrepository': [12, 0, 0, 0, 0, 0, 0, 0, 0],
#              'myid': [6, 0, 0, 1, 0, 1, 0, 0, 0],
#              'cosnumer': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'plugins': [0, 0, 1, 1, 0, 0, 0, 0, 0],
#              'indexmigrator': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'estimator': [20, 10, 30, 10, 1, 0, 0, 0, 0],
#              'foot': [0, 0, 2, 0, 0, 0, 0, 0, 0],
#              'uploadphoto': [3, 0, 0, 0, 0, 0, 0, 0, 0],
#              'willingness': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'tbatchaddressrowcloud': [0, 0, 3, 2, 1, 0, 0, 0, 0],
#              'uprev': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'rtl': [0, 0, 2, 11, 8, 0, 0, 0, 0],
#              'bytecodegeneratingentityinstantiator': [0,
#               0,
#               1,
#               0,
#               0,
#               0,
#               0,
#               0,
#               0],
#              'autoscroll': [0, 0, 3, 0, 0, 0, 0, 0, 0],
#              'referenceerror': [3, 2, 0, 1, 13, 2, 0, 0, 0],
#              'hyperlinks': [3, 0, 0, 3, 0, 2, 0, 0, 0],
#              'infor': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'taxonomy': [3, 2, 2, 0, 0, 0, 0, 0, 0],
#              'predecesor': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'mycomposedmodule': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'uncover': [1, 0, 2, 2, 2, 0, 0, 0, 1],
#              'temporary': [52, 32, 28, 26, 6, 0, 0, 0, 0],
#              'openblas': [1, 0, 0, 0, 0, 0, 0, 0, 0],
#              'infinitum': [0, 0, 0, 0, 1, 0, 0, 0, 0],
#              'misspelling': [2, 0, 0, 0, 0, 0, 0, 0, 0],
#              'staticdrawinfo': [0, 1, 0, 0, 0, 0, 0, 0, 0],
#              'rebuild': [8, 8, 36, 28, 27, 4, 2, 1, 1],
#              'hybrid': [0, 0, 2, 3, 4, 3, 0, 0, 0],
#              'httplistener': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'load': [132, 98, 173, 233, 138, 37, 15, 4, 1],
#              'projetc': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'lear': [0, 0, 1, 0, 0, 0, 0, 0, 0],
#              'pk': [0, 3, 0, 6, 1, 1, 0, 0, 0],
#              'filterattribute': [0, 0, 0, 2, 0, 0, 0, 0, 0],
#              ...})

# %%
def doc_feature_extraction(doc, vocab_features):
    doc_feautures = np.zeros(9, dtype='int')
    for token in doc:
        doc_feautures += vocab_features[token]
#     # init with bias
#     doc_feautures = np.insert(doc_feautures, 0, 1, axis=0)
        
    return  doc_feautures

# %%
def corpus_feature_extraction(corpus, vocab_features):
    corpus_features = [doc_feature_extraction(doc, vocab_features) for doc in corpus]
    
    return corpus_features

# %%
corpus_features = corpus_feature_extraction(corpus, vocab_features)

# %%
# example
print("Document:\n", corpus[0], '\n')
print("Feature vector of the document:", corpus_features[0])
# Out:
# Document:
#  ['add', 'object', 'literal', 'function', 'invocation', 'idea', 'metadata', 'capture', 'type', 'function', 'arg', 'able', 'create', 'instance', 'type', 'object', 'literal', 'arg', 'function', 'invocation', 'example']
#
# Feature vector of the document: [5249 4234 5533 7194 5265 1919  685  553   90]

# %%
from sklearn.manifold import TSNE

model = TSNE(n_components=2, random_state=42)

tsne_data = model.fit_transform(corpus_features)
# creating a new data frame which help us in ploting the result data
tsne_data = np.vstack((tsne_data.T, labels)).T
tsne_df = pd.DataFrame(data=tsne_data, columns=('dim_1','dim_2', 'label'))
# Ploting the result of tsne
sns.FacetGrid(tsne_df, hue='label', size=6).map(plt.scatter, 'dim_1','dim_2').add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Classification and prediction with frequency features

# %%
features_train, features_test, labels_train, labels_test = train_test_split(corpus_features, labels, test_size=0.3, random_state=111)

# %%
svc = LinearSVC(multi_class='crammer_singer')
knc = KNeighborsClassifier(n_neighbors=50)
mnb = MultinomialNB(alpha=0.2)
dtc = DecisionTreeClassifier(min_samples_split=7, random_state=111)
lrc = LogisticRegression(solver='lbfgs', penalty='l2', multi_class='multinomial', max_iter=10000)
rfc = RandomForestClassifier(n_estimators=31, random_state=111)
abc = AdaBoostClassifier(n_estimators=62, random_state=111)
bc = BaggingClassifier(n_estimators=9, random_state=111)
etc = ExtraTreesClassifier(n_estimators=9, random_state=111)

# %%
clfs = {'SVC' : svc,'KN' : knc, 'NB': mnb, 'DT': dtc, 'LR': lrc, 'RF': rfc, 'AdaBoost': abc, 'BgC': bc, 'ETC': etc}

# %%
def train_clf(clf, train_x, train_y):
    clf.fit(train_x, train_y)

# %%
def predict_labels(clf, features):
    return (clf.predict(features))

# %%
freq_pred_scores = []
for k,v in clfs.items():
    train_clf(v, features_train, labels_train)
    pred = predict_labels(v,features_test)
    freq_pred_scores.append((k, [accuracy_score(labels_test,pred)]))
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
df = pd.DataFrame.from_items(freq_pred_scores, orient='index', columns=['Score'])
df.sort_values(by=['Score'])
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   """Entry point for launching an IPython kernel.
#              Score
# SVC       0.076096
# NB        0.237438
# DT        0.237598
# BgC       0.263285
# ETC       0.263606
# AdaBoost  0.263606
# RF        0.281426
# KN        0.287044
# LR        0.293948

# %%
df.sort_values(by=['Score']).plot(kind='bar', figsize=(11,6), ylim=(0.1,1.0));

# %%
freq_pred_scores
# Out:
# [('DT', [0.23759833039011077]),
#  ('ETC', [0.26360571520308235]),
#  ('KN', [0.28704446941724193]),
#  ('RF', [0.2814255899823407]),
#  ('SVC', [0.07609568148980575]),
#  ('NB', [0.23743779097768503]),
#  ('LR', [0.2939476641515492]),
#  ('BgC', [0.26328463637823085]),
#  ('AdaBoost', [0.26360571520308235])]

# %%
freq_pred_scores_sorted = sorted(freq_pred_scores, key=lambda x: x[0])
freq_pred_scores_sorted
# Out:
# [('AdaBoost', [0.26360571520308235]),
#  ('BgC', [0.26328463637823085]),
#  ('DT', [0.23759833039011077]),
#  ('ETC', [0.26360571520308235]),
#  ('KN', [0.28704446941724193]),
#  ('LR', [0.2939476641515492]),
#  ('NB', [0.23743779097768503]),
#  ('RF', [0.2814255899823407]),
#  ('SVC', [0.07609568148980575])]
